# %%
from iminuit import Minuit
import matplotlib.pyplot as plt
from matplotlib import transforms
from matplotlib import rc
from IPython.display import Image
import numpy as np
from astropy.io import fits as pyfits
from astropy.io import fits
from scipy.ndimage import gaussian_filter
import scipy
from scipy.optimize import minimize, rosen, rosen_der
from scipy.special import factorial
import scipy.integrate as integrate
from scipy.integrate import quad
from itertools import starmap
from scipy import optimize
import corner
import time
from mpl_toolkits import mplot3d
import healpy as hp
from scipy import nan
import dark_matter_jfactors as dmj
import math
import random
import importlib
from pymultinest.solve import solve
import pymultinest
import warnings
warnings.filterwarnings("ignore")
import scipy as sp
import scipy.interpolate
import json
from os import walk
import re

# %%
filelist = ['Bremss_00320087_E_50-814008_MeV_healpix_128.fits', 'Bremss_SL_Z6_R20_T100000_C5_E_50-814008_MeV_healpix_128.fits', 'pi0_Model_A_E_50-814008_MeV_healpix_128.fits', 'pi0_Model_F_E_50-814008_MeV_healpix_128.fits', 'ICS_Model_A_E_50-814008_MeV_healpix_128.fits', 'ICS_Model_F_E_50-814008_MeV_healpix_128.fits']
evermore_shifted = np.asarray([
    [33, 21, 49],
    [154, 112, 82],
    [241, 149, 91],
    [142, 52, 38],
    [33, 21, 49],
])/256

#exposure_time = 4.1e6 #.13 years 47 days
#exposure_time = 4.1e8 #13 years
#exposure_time = 4.1e9 #130 years
#exposure_time = 4.1e11 #13000 years
exposure_time = 4.1e15 #1 billion years
#exposure_time = 3.154e8 #10 years

# %%
def log_interp1d(xx, yy, kind='linear'):
    logx = np.log10(xx)
    logy = np.log10(yy)
    lin_interp = sp.interpolate.interp1d(logx, logy, kind=kind, fill_value="extrapolate")
    log_interp = lambda zz: np.power(10.0, lin_interp(np.log10(zz)))
    return log_interp

def get_all_egb_data(energies, deltae):
    energy_range = np.array([(.1, .14), (.14, .2), (.2, .28), (.28, .4), (.4, .57), (.57, .8), (.8, 1.1), (1.1, 1.6), (1.6, 2.3), (2.3, 3.2), (3.2, 4.5), (4.5, 6.4), (6.4, 9.1), (9.1, 13), (13, 18), (18, 26), (26, 36), (36, 51), (51, 72), (72, 100), (100, 140), (140, 200), (200, 290), (290, 410), (410, 580), (580, 820)])*1e3 #GeV to MeV
    egb_intensity = np.array([3.7e-6, 2.3e-6, 1.5e-6, 9.7e-7, 6.7e-7, 4.9e-7, 3e-7, 1.8e-7, 1.1e-7, 6.9e-8, 4.2e-8, 2.6e-8, 1.7e-8, 1.2e-8, 6.8e-9, 4.4e-9, 2.7e-9, 1.8e-9, 1.1e-9, 6.2e-10, 3.1e-10, 1.9e-10, 8.9e-11, 6.3e-11, 2.1e-11, 9.7e-12])
    middle_bin = []
    bin_width = []
    for i in range(0, len(energy_range)):
        low_e = np.log10(energy_range[i][0])
        high_e = np.log10(energy_range[i][1])
        difference = np.abs((low_e+high_e)/2)
        middle_bin.append(10**(difference))
        bin_width.append(np.abs(energy_range[i][1]-(10**(difference)))) 
    return middle_bin, bin_width, egb_intensity

def get_all_egb(energies, deltae):
    energy_range = np.array([(.1, .14), (.14, .2), (.2, .28), (.28, .4), (.4, .57), (.57, .8), (.8, 1.1), (1.1, 1.6), (1.6, 2.3), (2.3, 3.2), (3.2, 4.5), (4.5, 6.4), (6.4, 9.1), (9.1, 13), (13, 18), (18, 26), (26, 36), (36, 51), (51, 72), (72, 100), (100, 140), (140, 200), (200, 290), (290, 410), (410, 580), (580, 820)])*1e3 #GeV to MeV
    egb_intensity = np.array([3.7e-6, 2.3e-6, 1.5e-6, 9.7e-7, 6.7e-7, 4.9e-7, 3e-7, 1.8e-7, 1.1e-7, 6.9e-8, 4.2e-8, 2.6e-8, 1.7e-8, 1.2e-8, 6.8e-9, 4.4e-9, 2.7e-9, 1.8e-9, 1.1e-9, 6.2e-10, 3.1e-10, 1.9e-10, 8.9e-11, 6.3e-11, 2.1e-11, 9.7e-12])
    middle_bin = []
    bin_width = []
    for i in range(0, len(energy_range)):
        low_e = np.log10(energy_range[i][0])
        high_e = np.log10(energy_range[i][1])
        difference = np.abs((low_e+high_e)/2)
        middle_bin.append(10**(difference))
        bin_width.append(np.abs(energy_range[i][1]-(10**(difference)))) 
        

    log_interp = log_interp1d(middle_bin, egb_intensity/bin_width, kind='linear')
    
    '''
    print(egb_intensity[2]/bin_width[2]*deltae[6])
    print(energies[6])
    x_trapz = np.logspace(np.log10(np.nanmin(energies)), np.log10(np.nanmax(energies)), num = 100)
    plt.scatter(middle_bin, egb_intensity/bin_width)
    plt.plot(x_trapz, log_interp(x_trapz), color = 'red')
    plt.scatter(energies[6], log_interp(energies[6]), color = 'green')
    plt.yscale('log')
    plt.xscale('log')
    '''
    
    counts = []
    #only want energies from 3 onward (about lowest at 80 MeV)
    for x in range(3, len(energies)):
        highest_val = energies[x]+deltae[x]
        lowest_val = energies[x]-deltae[x]
        x_trapz = np.logspace(np.log10(lowest_val), np.log10(highest_val), num = 400)
        #counts.append(log_interp(energies[x])*deltae[x])
        total_counts = np.trapz(log_interp(x_trapz), x = x_trapz)
        
        #print('total counts: {}'.format(total_counts))
        '''
        plt.scatter(middle_bin, egb_intensity/bin_width)
        plt.plot(x_trapz, log_interp(x_trapz), color = 'red')
        plt.scatter(energies[x], total_counts)
        
        plt.yscale('log')
        plt.xscale('log')
        asdfads
        '''
        counts.append(total_counts)  
    return counts #returns counts per cm^2 per sec per str

# %%
def readfile(filename):
    """
    A simple function to read the maps of a given number n and given filename.
    """
    file_to_read = fits.open(filename)
    return file_to_read

def reshape_file(hdu, n, inner20 = True):
    """
    Reshapes the data to be in the size we want
    """
    
    if inner20:
        numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
        NSIDE = int(hdu[0].header['NSIDE'])
        degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
        inner_20_pos = np.where(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
        inner_20_neg = np.where(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
        testbin = list(hdu[n].data[inner_20_pos])+list(hdu[n].data[inner_20_neg])
        
        #might need this for plotting, not sure
        #data4 = hdu[n].data
        #test20 = np.copy(data4)
        #test20[inner_20] = np.nan
        #testbin = np.reshape(test20, (128*3, 1536//3))

    else:
        """
        testbin = np.reshape(hdu[n].data, (128*3, 1536//3))
        
        """
        numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
        NSIDE = int(hdu[0].header['NSIDE'])
        degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
        
        inner_20_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
        inner_20_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
        inner_20 = np.logical_and(inner_20_pos, inner_20_neg)
        
        data4 = hdu[n].data
        test20 = np.copy(data4)
        #test20[inner_20] = np.nan
        #print(sum(~np.isnan(test20)))
        testbin = np.reshape(test20, (128*3, 1536//3))
        
    return testbin

def get_energy_index(E_desired, hdu):
    energy_hdu = np.concatenate(hdu[38].data, axis = 0)
    idx = find_nearest(energy_hdu, E_desired)
    return idx
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
def subtract(n):
    ##Template for 1 GeV and 10 GeV
    icsa = readfile(filelist[n])
    
    idx1 = get_energy_index(1*1e3, icsa)
    idx10 = get_energy_index(10*1e3, icsa)
    
    array1 = reshape_file(icsa, idx1, inner20 = False)
    array10 = reshape_file(icsa, idx10, inner20 = False)
    
    ##Sum up idx1 and idx 10, make them equal in sum
    sum1 = np.nansum(array1)
    sum10 = np.nansum(array10)
    array10_adjusted = (array10*sum1/sum10)
    subtract110 = np.abs(array1-array10_adjusted)/array1
    fig, ax = plt.subplots(figsize=(10, 10))
    image = ax.imshow(subtract110)
    fig.colorbar(image, ax=ax, anchor=(0, 0.3), shrink=0.7)
    plt.title(str(filelist[n]))
    
    return

# %%
#n = 4 for ICSA, n = 2 for pi0
def psf_smoothing(n, energyidx, inner20psf = False):
    icsa = readfile(filelist[n])

    inner20psf = False
    
    data50 = reshape_file(icsa, energyidx, inner20 = inner20psf) #get the data at 50 MeV
    

    
    #data50_convolved = gaussian_filter(data50, sigma=0) #PSF off
    data50_convolved = np.copy(data50)
    
    
    hdu = readfile(filelist[n])
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    
    data50_convolved = data50_convolved.flatten()

    degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
    inner_20_pos = np.where(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg = np.where(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_pos_forsum = np.argwhere(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg_forsum = np.argwhere(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_true_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
    inner_20_true_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
    inner_20 = np.logical_and(inner_20_true_pos, inner_20_true_neg)
    
    initsum = np.nansum(list(data50.flatten()[inner_20_pos_forsum]) + list(data50.flatten()[inner_20_neg_forsum]))
    
    data50_convolved[inner_20] = np.nan
    plotimage = np.reshape(data50_convolved, (128*3, 1536//3))
    #plt.imshow(np.log10(plotimage))
    #plt.show()
    #plt.close()
    
    testbin = list(data50_convolved[inner_20_pos])+list(data50_convolved[inner_20_neg])
    finsum = np.nansum(testbin)

    return np.array(testbin)*initsum/finsum

def psf_smoothing_DM(energyidx, crosssec = 2.2e-26, anal_data = False, mass_dm = 100):
    energybin = np.concatenate(readfile(filelist[0])[38].data, axis = 0)[energyidx]
    bins_in_lin = np.log10(energybin)
    deltae = get_deltaE(energyidx)
    
    highe = (energybin+deltae)/1e3 #convert to GeV
    lowe = (energybin-deltae)/1e3
    
    hdu = readfile(filelist[0])
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    
    degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
    inner_20_pos = np.where(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg = np.where(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_pos_forsum = np.argwhere(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg_forsum = np.argwhere(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_true_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
    inner_20_true_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
    inner_20 = np.logical_and(inner_20_true_pos, inner_20_true_neg)
    
    
    #need to make sure the initsum is *only within the inner 20 degrees, same for finsum
    data50 = dmj.get_dNdE(highe, lowe, sigmav = crosssec, analyze_data = anal_data, massx = mass_dm)[1] #photons per cm^2 per sec per str per MeV
    

    
    initsum = np.nansum(list(data50.flatten()[inner_20_pos_forsum]) + list(data50.flatten()[inner_20_neg_forsum]))
    data50_convolved = np.copy(data50)
    #data50_convolved = gaussian_filter(data50, sigma=0) #psf off
    data50_convolved = data50_convolved.flatten()
    data50_convolved[inner_20] = np.nan
    plotimage = np.reshape(data50_convolved, (128*3, 1536//3))
    #plt.imshow(np.log10(plotimage))
    #plt.show()
    #plt.close()


    testbin = list(data50_convolved[inner_20_pos])+list(data50_convolved[inner_20_neg])
    finsum = np.nansum(testbin) #photons per cm^2 per sec per str per MeV
    
    return np.array(testbin)*initsum/finsum

def poisson_dist(n, energyidx, cross_section =2.2e-26, dm = False, analyze_data = False, dm_mass = 100, egb = False, counts = 0):   
    '''
    Performs a PSF smoothing of the array, before converting it into photons per pixel
    
    '''
    deltaE = get_deltaE(energyidx)
    if dm:
        convolved_data = psf_smoothing_DM(energyidx, cross_section, anal_data = analyze_data, mass_dm = dm_mass)/deltaE
    elif egb:
        convolved_data_init = np.empty(5910)
        convolved_data_init.fill(1)
        convolved_data = convolved_data_init*counts #in units of photons per cm^2 per mev per str per sec
    else:
        convolved_data = psf_smoothing(n, energyidx, cross_section) #data in units of photons cm^-2 MeV^-1 str^-1
    deltaomega = 4*np.pi/196608 #divide by num of pixels
    n_gamma = np.array(convolved_data)*deltaE*exposure_time*8500*deltaomega*.2 #13 years*.85meters^2, units of photons per pixel
    
    return n_gamma

def get_deltaE(n):
    energybins = np.concatenate(readfile(filelist[0])[38].data, axis = 0)
    bins_in_lin = np.log10(energybins)[n]
    spacing = 0.05691431
    
    high_bin = 10**(bins_in_lin + spacing)
    low_bin = 10**(bins_in_lin - spacing)
    
    deltaE = np.abs(high_bin - low_bin)
    #print('delta E: {}'.format(deltaE))
    
    return deltaE

def get_image(data):
    fig, ax = plt.subplots(figsize=(10, 10))
    image = ax.imshow(data)
    fig.colorbar(image, ax=ax, anchor=(0, 0.3), shrink=0.7)
    return

def simulated_data(energyidx, templates):
    
    '''
    Use PSF smoothed data to create a random poisson draw to obtain simulated data
    '''
    
    
    n_gammatot = 0
    for i in range(0, len(templates)):
        n_gammatot += templates[i]
    len_of_rand = len(n_gammatot)
    simdata = np.zeros(len_of_rand)
    randdata = np.random.rand(len_of_rand)
    
    for i in range(0, len_of_rand):
        #print(n_gammatot[i])
        if n_gammatot[i]<.01:
            if n_gammatot[i] < randdata[i]:
                simdata[i] = 0
            else:
                simdata[i] = 1
        else:
            simdata[i] = np.random.poisson(lam = n_gammatot[i])
    #print('simdata just 20: ', np.nansum(simdata))
    
    return simdata

def minimize_likelihood(energyidx, cross_sec = 2.2e-26, massdm = 100):
    pi = poisson_dist(2, energyidx)
    ics = poisson_dist(4, energyidx)   
    brem = poisson_dist(0, energyidx)

    darkm = poisson_dist(np.nan, energyidx, cross_section = cross_sec, dm = True, dm_mass = massdm)

    k = simulated_data(energyidx, [pi, ics, brem])#remove DM for accurate
    #print(np.nanmean(lamb))
    #asdfasd
    
    #Need to minimize for lamb < 50 and lamb > 50
    
    bnds = ((0, np.inf), (0, np.inf), (0, np.inf), (1e-30, np.inf))
    result = minimize(likelihood, (1, 1, 1, 1), args = (k, pi, ics, brem, darkm), bounds = bnds)
    min_likelihood = result.x
    chi2 = result.fun
    #print(result)

    return min_likelihood


def likelihood(constants, k, pi, ics, brem, dm):
    """
    Gets the Total Likelihoods from the Gaussian Regime and the Poisson Regime
    Once each has been calculated, multiplies values together for final likelihood
    """
    
    likelihood_poiss = likelihood_poisson(constants, k, pi, ics, brem, dm)
    #print('likelihood: {}'.format(likelihood_poiss)) 
    return likelihood_poiss

def merge(list1, list2):
      
    merged_list = tuple(zip(list1, list2)) 
    return merged_list

def likelihood_gaussian(constants, lamb, pi, ics):
    sigma = np.sqrt(constants[0]*pi+constants[1]*ics)
    mu = lamb
    rng = 0.5
    
    #flatten arrays
    sigma_flat = sigma.flatten()
    mu_flat = mu.flatten()
    length_flattened = len(mu_flat)
    #get arrays in sigma, mu tuple format
    ms_tuples = list(merge(mu_flat, sigma_flat))
    ms = np.array(ms_tuples, dtype = 'f,f')
    lower_bound_arr = mu_flat - rng
    upper_bound_arr = mu_flat + rng
    
    args = np.concatenate((np.full((length_flattened, 1), prob_func), lower_bound_arr.reshape((length_flattened, 1)), upper_bound_arr.reshape((length_flattened, 1)), ms.reshape((length_flattened, 1))), axis = 1)
    
    #log likelihood
    prob = list(starmap(lambda a, b, c, d: quad(a, b, c, d)[0], args))

    #reshape for testing
    l = np.sum(np.log(prob))
    likely = -2*l
    
    return likely
    
def prob_func(x, mu, sigma):
    probdens = 1/(sigma*np.sqrt(2*np.pi))*np.exp(-1/2*((x-sigma**2)/sigma)**2)
    return probdens

#def likelihood_poisson(a0):
def likelihood_poisson(a0, a1, a2, a3, a4):
#def likelihood_poisson(constants, ktest, pitest, icstest, bremtest, dmtest):
    lamb = a0*pitest+a1*icstest+a2*bremtest+a3*darkmtest+a4*egbtest
    #lamb = a0*egbtest
    
    #print(a0, a1, a2, a3)
    #print(lamb)

    #lamb = constants[0]*pitest+constants[1]*icstest+constants[2]*bremtest+constants[3]*dmtest
    
    fprob = -scipy.special.gammaln(ktest+1)+ktest*np.log(lamb)-lamb #log likelihood of poisson
    #print(fprob)
    return -2*np.nansum(fprob)

def get_curves(n, energyidx, inner20psf = True):
    icsa = readfile(filelist[n])
    data50 = reshape_file(icsa, energyidx, inner20 = inner20psf) #get the data at energyidx MeV
    delt = get_deltaE(energyidx)
    return np.asarray(data50)*exposure_time*8500*.2*delt #13 years * .85 m^2 * .2, return in photons /str
    
def get_normalizations_spectrum(deltaE, cross_sec = 2.2e-26, dm_mass = 100):
    
    
    hdu = readfile(filelist[0])
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    
    degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
    inner_20_pos = np.where(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg = np.where(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_pos_forsum = np.argwhere(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
    inner_20_neg_forsum = np.argwhere(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
    inner_20_true_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
    inner_20_true_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
    inner_20 = np.logical_and(inner_20_true_pos, inner_20_true_neg)
    
    range_templates = [2, 4, 0] #pi, ics, brem
    e = readfile(filelist[0])[38].data
    energies = np.array(list(e)).T[0]
    templates = []
    temp = []
    deltaomega = 4*np.pi/196608 #i think this should maybe still be total bins in whole image pre-20?
    
    for n in range_templates:
        temp = []
        for index in range(3, len(energies)):
            temp.append(np.nansum(get_curves(n, index))) #units of photons per str
        templates.append(np.asarray(temp)*deltaomega) #gets counts per bin
    
    #dark matter template
    
    dm_temp = []
    dm_templates_tot = []
    for index in range(3, len(energies)):
        energybin = np.concatenate(readfile(filelist[0])[38].data, axis = 0)[index]
        bins_in_lin = np.log10(energybin)
        deltae = get_deltaE(index)
    
        highe = (energybin+deltae)/1e3
        lowe = (energybin-deltae)/1e3
        #data50 = dmj.get_dNdE(highe, lowe, sigmav = cross_sec, massx = dm_mass, for_normals = True)[1] #units of photons cm^-2 str^-1 per sec not per MeV?
        data50 = dmj.get_dNdE(highe, lowe, sigmav = cross_sec, massx = dm_mass, for_normals = False)[1]
        initsum = np.nansum(list(data50.flatten()[inner_20_pos_forsum]) + list(data50.flatten()[inner_20_neg_forsum]))
        
        #dm_temp.append(np.nansum(data50))
        #dm_temp.append(np.nansum(data50)*exposure_time*8500) #13 years * .85 m^2 * .2, return in photons/str
        dm_temp.append(initsum*exposure_time*8500) #13 years * .85 m^2 * .2, return in photons/str
    dm_templates_tot.append(np.asarray(dm_temp)*deltaomega) #photons per pixel?
    #print(np.nansum(dm_templates_tot[0]))
    
    
    
    
    #EGB template
    egb_templates = np.array(get_all_egb(energies, deltaE)) #units of counts per cm^2 per sec per str
    egb_temp_fin = egb_templates*8500*exposure_time*deltaomega #counts per bin
    
    
    #return range_templates, energies, [np.array(dm_templates_tot)[0]*.2, np.array(egb_temp_fin)*.2]
    #return range_templates, energies, [np.array(templates[0])*.2, np.array(templates[1])*.2, np.array(templates[2])*.2]
    return range_templates, energies, [np.array(templates[0])*.2, np.array(templates[1])*.2, np.array(templates[2])*.2, np.array(dm_templates_tot)*.2, np.array(egb_temp_fin)*.2] #counts per pixel
    
    
def get_normalized(energyidx, normals, template_val, energies):
    '''
    Normalizes the ROI based on the shape the spectrums should have
    
    
    Do not need to use this, as long as you stay consistent across all Fermi data
    for the exposure time and collecting area
    
    '''
    
    poisson_pi = poisson_dist(template_val, int(energyidx)) #units of photons per pixel
    init_sum_pi = np.nansum(poisson_pi)
    #print(np.nansum(init_sum_pi))
    if template_val == 2:
        normval = 0
    if template_val == 4:
        normval = 1
    if template_val == 0:
        normval = 2
    print('normval for pi at 0: {}'.format(normals[normval][energyidx])) 
    print('delta E at 0: {}'.format(get_deltaE(energyidx)))
    normal_pi = normals[normval][energyidx]*get_deltaE(energyidx)
    pitest = poisson_pi*normal_pi/init_sum_pi
    print('normalization: {}'.format(np.nansum(pitest)))
    #print(np.nansum(pitest))
    
    #print('----------------------')
    
    return pitest

# %%
def get_darksusy_counts():
    x = np.loadtxt('yield_DS_keith100.dat', dtype=str).T
    energies = x[1].astype(np.float)*1e3
    yieldperann = x[2].astype(np.float)/1e3 #convert from per GeV to per MeV
    energybins = np.concatenate(readfile(filelist[0])[38].data, axis = 0)
    
    counts = []
    delta = []
    for n in range(0, 38):
        
        bins_in_lin = energybins[n]
        deltae = get_deltaE(n)
    
        highe = (bins_in_lin+deltae)
        lowe = (bins_in_lin-deltae)
        
        good_energies = np.where((energies <=highe) & (energies >= lowe))
        
        final_integral = np.trapz(yieldperann[good_energies], x = energies[good_energies])

        counts.append(final_integral)
        delta.append(deltae)
    return np.array(counts), np.array(delta)

# %%
hdu = readfile(filelist[0])
numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
NSIDE = int(hdu[0].header['NSIDE'])
    
degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
inner_20_pos = np.where(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
inner_20_neg = np.where(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
inner_20_pos_forsum = np.argwhere(np.sqrt((degrees[0])**2+degrees[1]**2)<= 20)
inner_20_neg_forsum = np.argwhere(np.sqrt((degrees[0]-360)**2+degrees[1]**2)<= 20)
inner_20_true_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
inner_20_true_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
inner_20 = np.logical_and(inner_20_true_pos, inner_20_true_neg)
    
    
range_templates = [2, 4, 0] #pi, ics, brem
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
templates = []
temp = []
deltaomega = 4*np.pi/196608 #i think this should maybe still be total bins in whole image pre-20?
cross_sec = 2.2e-26
dm_mass = 100

counts, deltae = get_darksusy_counts()

dm_temp = []
dm_templates_tot = []
for index in range(3, len(energies)):
    energybin = np.concatenate(readfile(filelist[0])[38].data, axis = 0)[index]
    bins_in_lin = np.log10(energybin)
    deltae = get_deltaE(index)
    
    highe = (energybin+deltae)/1e3
    lowe = (energybin-deltae)/1e3
    #data50 = dmj.get_dNdE(highe, lowe, sigmav = cross_sec, massx = dm_mass, for_normals = True)[1] #units of photons cm^-2 str^-1 per sec not per MeV?
    data50 = dmj.get_dNdE(highe, lowe, sigmav = cross_sec, massx = dm_mass, for_normals = True)[1]
    print(np.nansum(data50))
    break
# Out:
# mass of dark matter: 100
# 3.936274634459639e-08

# %%
print(normals[])

# %%
#start by testing egb I suppose

importlib.reload(dmj)
#gets darksusy counts for a specific dark matter mass
counts, deltae = get_darksusy_counts()
#be sure to change the dm mass
temps, energies, normals = get_normalizations_spectrum(deltae, cross_sec = 2.2e-26) #photons per pixel
# Out:
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100
# mass of dark matter: 100

# %%
#main chunk of code now
#testing pymultinest



#code that returns the log-likelihood at a specific point. cube is first parameter, everything else are random parameters
#that are not part of the fitting cube
def likelihood_poisson_multinest(cube, pitest, icstest, bremtest, darkmtest, egbtest, ktest):
    a0 = 10**cube[0]
    a1 = 10**cube[1]
    a2 = 10**cube[2]
    a3 = 10**cube[3]
    a4 = 10**cube[4]
    lamb = a0*pitest+a1*icstest+a2*bremtest+a3*darkmtest+a4*egbtest
    fprob = -scipy.special.gammaln(ktest+1)+ktest*np.log(lamb)-lamb #log likelihood of poisson
    return 2*np.sum(fprob) #perhaps add negative back, perhaps add 2 back?

##This is the prior function, it is flat in linear space, from a minimum value specified by the first number, 
#to a maximum number specified by the first number + the second number. 
#The variables were called a/b/c/phi0/phi1/norm in this code.
#You need to define a prior for every parameter you send

def prior(cube, ndim, nparams):
    cube[0] = (cube[0]*2 - 1) #from 1e-4 to 1e10 apparently
    cube[1] = (cube[0]*2 - 1)
    cube[2] = (cube[2]*2 - 1)
    cube[3] = (cube[3]*2 - 1)
    cube[4] = (cube[4]*2 - 1)
    return cube

##This is the loglikelihood function for multinest – it sends the cube,
#and then a bunch of different arrays that were used in fitting, but were constant, to the pymultinest code
def loglikelihood_formulti(cube, ndim, nparms):
    return likelihood_poisson_multinest(cube, pitest, icstest, bremtest, darkmtest, egbtest, ktest)
    #return likelihood_poisson_multinest(cube, pitest, icstest, bremtest, darkmtest, egbtest, ktest)
    

#getting errors and stuff for the dark matter stuff
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points = []
errors = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:])


#EGB getting now, first get all the counts at each energy bin
egb_counts = get_all_egb(energies, deltae)/deltae_cut #units of counts per cm^2 per sec per str per MeV
counting = 0

##These are the names of the parameters we are fitting.
parameters = ['a0', 'a1', 'a2', 'a3', 'a4']
#parameters = ['a0', 'a1']
#parameters = ['a0']

folder = './pymultinest_chains/'
livepoints = 200

'''Check if directory exists, if not, create it'''
import os

# You should change 'test' to your preferred folder.
MYDIR1 = (folder + "all")
CHECK_FOLDER = os.path.isdir(MYDIR1)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR1)
    print("created folder : ", MYDIR1)

else:
    print(MYDIR1, "folder already exists.")

#getting the constants in front of the poission dist. arrays
for energyidx in range(3, len(energies)):
#for energyidx in range(3, 7):
    # You should change 'test' to your preferred folder.
    MYDIR = (MYDIR1 + "/chain" + str(energyidx))
    CHECK_FOLDER = os.path.isdir(MYDIR)

    # If folder doesn't exist, then create it.
    if not CHECK_FOLDER:
        os.makedirs(MYDIR)
        print("created folder : ", MYDIR)

    else:
        print(MYDIR, "folder already exists.")
    print(energyidx, energies[energyidx])
    
    start_time = time.time()
    pitest = poisson_dist(2, int(energyidx))
    icstest = poisson_dist(4, int(energyidx))
    bremtest = poisson_dist(0, int(energyidx))
    print("--- %s seconds to get base templates---" % (time.time() - start_time))
    


    #EGB counts, we have at each energy bin in units of per cm^2 per s per str per MeV
    egbtest = poisson_dist(np.nan, int(energyidx), egb = True, counts = egb_counts[counting])

    importlib.reload(dmj) 
    darkmtest = poisson_dist(np.nan, int(energyidx), dm = True, cross_section = 2.2e-26, analyze_data = False)

    darkmtest[np.isnan(darkmtest)] = 0
    
    

    #gotta add egbtest to the ktest
    

    start_time = time.time()
    #ktest = simulated_data(int(energyidx), [darkmtest, egbtest])
    ktest = simulated_data(int(energyidx), [pitest, icstest, bremtest, darkmtest, egbtest])
    print("--- %s seconds to get ktest---" % (time.time() - start_time))
    
    ##This is the main part of the code – it tells pymultinest to run loglikelihood in a loop – 
    #with 6 variables defined in the prior function, and send the output to the folder we specified.
    #N_live_points tells you how many different chains to test (usually 200-1000)
    ##json.dump (requires import json) saves the output into a parameters file.
    #result = solve(LogLikelihood=likelihood_poisson_multinest, Prior=prior, n_dims=int(len(parameters)), outputfiles_basename=folder+"/params", verbose=True)
    
    start_time = time.time()
    finals = pymultinest.run(loglikelihood_formulti, prior, int(len(parameters)), outputfiles_basename=MYDIR+"/"+ str(energyidx), n_live_points=livepoints, resume=True, verbose=True)
    print("--- %s seconds to minimize func---" % (time.time() - start_time))
    print('made it to here')
    json.dump(parameters, open(MYDIR+'/' + str(energyidx) + 'params' +'.json', 'w'))
    counting += 1
    print('----------')

print('------------------')

#we now have our constants. Let's get back our adjusted plots
# Out:
# created folder :  ./pymultinest_chains/all
# created folder :  ./pymultinest_chains/all/chain3
# 3 109.7629710930695
# --- 0.1980431079864502 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008048295974731445 seconds to get ktest---
# --- 8.622754096984863 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain4
# 4 142.65416981671697
# --- 0.2234632968902588 seconds to get base templates---
# mass of dark matter: 100
# --- 0.007987260818481445 seconds to get ktest---
# --- 11.06626009941101 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain5
# 5 185.40143331981702
# --- 0.22407078742980957 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008540868759155273 seconds to get ktest---
# --- 14.305370807647705 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain6
# 6 240.95819646356009
# --- 0.21251773834228516 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008473873138427734 seconds to get ktest---
# --- 13.998761892318726 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain7
# 7 313.1629103579625
# --- 0.2308330535888672 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008199930191040039 seconds to get ktest---
# --- 13.760731935501099 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain8
# 8 407.0042433219344
# --- 0.2501189708709717 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008212089538574219 seconds to get ktest---
# --- 16.48579216003418 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain9
# 9 528.965751061358
# --- 0.2579331398010254 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008227825164794922 seconds to get ktest---
# --- 14.441957950592041 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain10
# 10 687.4738295408508
# --- 0.23933076858520508 seconds to get base templates---
# mass of dark matter: 100
# --- 0.007951021194458008 seconds to get ktest---
# --- 14.875319004058838 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain11
# 11 893.4798998900418
# --- 0.2455310821533203 seconds to get base templates---
# mass of dark matter: 100
# --- 0.00793313980102539 seconds to get ktest---
# --- 12.851219177246094 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain12
# 12 1161.217048859432
# --- 0.2509891986846924 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008007287979125977 seconds to get ktest---
# --- 12.637898206710815 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain13
# 13 1509.1834015826835
# --- 0.28397583961486816 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008336782455444336 seconds to get ktest---
# --- 12.751944065093994 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain14
# 14 1961.420168477385
# --- 0.2658669948577881 seconds to get base templates---
# mass of dark matter: 100
# --- 0.007848978042602539 seconds to get ktest---
# --- 12.576627969741821 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain15
# 15 2549.1726673347453
# --- 0.2957460880279541 seconds to get base templates---
# mass of dark matter: 100
# --- 0.009140968322753906 seconds to get ktest---
# --- 13.858392000198364 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain16
# 16 3313.049081641206
# --- 0.25922489166259766 seconds to get base templates---
# mass of dark matter: 100
# --- 0.007916927337646484 seconds to get ktest---
# --- 12.926175117492676 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain17
# 17 4305.826105078932
# --- 0.23502898216247559 seconds to get base templates---
# mass of dark matter: 100
# --- 0.00905609130859375 seconds to get ktest---
# --- 16.64054822921753 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain18
# 18 5596.095315918128
# --- 0.5247848033905029 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008025884628295898 seconds to get ktest---
# --- 17.07210421562195 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain19
# 19 7273.00221156208
# --- 0.3006761074066162 seconds to get base templates---
# mass of dark matter: 100
# --- 0.014019012451171875 seconds to get ktest---
# --- 18.914573192596436 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain20
# 20 9452.405326071254
# --- 0.4124307632446289 seconds to get base templates---
# mass of dark matter: 100
# --- 0.015556097030639648 seconds to get ktest---
# --- 16.588578701019287 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain21
# 21 12284.880967903657
# --- 0.29952383041381836 seconds to get base templates---
# mass of dark matter: 100
# --- 0.01252889633178711 seconds to get ktest---
# --- 14.819505214691162 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain22
# 22 15966.126630150377
# --- 0.35802793502807617 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008291006088256836 seconds to get ktest---
# --- 13.713391780853271 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain23
# 23 20750.481851310695
# --- 0.24393606185913086 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008643865585327148 seconds to get ktest---
# --- 12.434079885482788 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain24
# 24 26968.50069123621
# --- 0.23917579650878906 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008095026016235352 seconds to get ktest---
# --- 11.757682085037231 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain25
# 25 35049.78991546971
# --- 0.27667808532714844 seconds to get base templates---
# mass of dark matter: 100
# --- 0.009169816970825195 seconds to get ktest---
# --- 10.966457843780518 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain26
# 26 45552.69079225364
# --- 0.24487805366516113 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008432149887084961 seconds to get ktest---
# --- 10.315700054168701 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain27
# 27 59202.85523591168
# --- 0.26990318298339844 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008224964141845703 seconds to get ktest---
# --- 10.006325006484985 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain28
# 28 76943.38154619717
# --- 0.26113200187683105 seconds to get base templates---
# mass of dark matter: 100
# --- 0.00881505012512207 seconds to get ktest---
# --- 9.49069595336914 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain29
# 29 99999.97365283336
# --- 0.307523250579834 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008355140686035156 seconds to get ktest---
# --- 10.659483909606934 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain30
# 30 129965.62575773097
# --- 0.3731379508972168 seconds to get base templates---
# mass of dark matter: 100
# --- 0.01815509796142578 seconds to get ktest---
# --- 9.96820592880249 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain31
# 31 168910.68328916508
# --- 0.3795309066772461 seconds to get base templates---
# mass of dark matter: 100
# --- 0.010501861572265625 seconds to get ktest---
# --- 8.35518503189087 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain32
# 32 219525.8843472731
# --- 0.3631889820098877 seconds to get base templates---
# mass of dark matter: 100
# --- 0.01778578758239746 seconds to get ktest---
# --- 7.865541219711304 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain33
# 33 285308.2644627702
# --- 0.3497490882873535 seconds to get base templates---
# mass of dark matter: 100
# --- 0.010171890258789062 seconds to get ktest---
# --- 7.217306137084961 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain34
# 34 370802.7689435847
# --- 0.3479790687561035 seconds to get base templates---
# mass of dark matter: 100
# --- 0.013437986373901367 seconds to get ktest---
# --- 6.220441102981567 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain35
# 35 481916.2659558049
# --- 0.2879350185394287 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008697271347045898 seconds to get ktest---
# --- 5.533699035644531 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain36
# 36 626325.6556968171
# --- 0.4536898136138916 seconds to get base templates---
# mass of dark matter: 100
# --- 0.008452892303466797 seconds to get ktest---
# --- 5.121728181838989 seconds to minimize func---
# made it to here
# ----------
# created folder :  ./pymultinest_chains/all/chain37
# 37 814008.272175696
# --- 0.3758668899536133 seconds to get base templates---
# mass of dark matter: 100
# --- 0.009102106094360352 seconds to get ktest---
# --- 4.643813133239746 seconds to minimize func---
# made it to here
# ----------
# ------------------

# %%
egbtest = poisson_dist(np.nan, int(3), egb = True, counts = egb_counts[0])
importlib.reload(dmj) 
darkmtest = poisson_dist(np.nan, int(3), dm = True, cross_section = 2.2e-26, analyze_data = False)

darkmtest[np.isnan(darkmtest)] = 0

ktest = simulated_data(int(energyidx), [darkmtest, egbtest])

plt.hist(ktest-(egbtest+darkmtest), bins = 20)
# Out:
# mass of dark matter: 100
# (array([  1.,   3.,  11.,  22.,  54., 138., 257., 405., 625., 796., 897.,
#         815., 702., 518., 344., 191.,  81.,  27.,  17.,   6.]),
#  array([-97028.50701487, -87952.96187391, -78877.41673295, -69801.871592  ,
#         -60726.32645104, -51650.78131008, -42575.23616912, -33499.69102817,
#         -24424.14588721, -15348.60074625,  -6273.05560529,   2802.48953567,
#          11878.03467662,  20953.57981758,  30029.12495854,  39104.6700995 ,
#          48180.21524045,  57255.76038141,  66331.30552237,  75406.85066333,
#          84482.39580429]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # Let's write a function that takes the normals and the results, and makes a plot with the error bars on it.

# %%
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points0 = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:])
units = deltae_cut*8500*exposure_time*4*np.pi/196608*.2
cut_energy = energies[3:]

def mini_data(path, normals):
    points0 = []
    f = []
    mypath = './pymultinest_chains/' + str(path) + '/'
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.append(dirnames)
    chains_list = f[0]

    for number in range(3, 4):
    #for number in range(3, range_num+3):
        file = 'chain' + str(number)
        number = re.sub('\D', '', str(file))
        path_to_this_file = mypath + file + '/' + str(number) + 'stats.json'
        f = open(path_to_this_file)
        filehere = json.load(f)
        print(path_to_this_file)
        pointhere = (10**(filehere['marginals'][0]['median']))
        print('pointhere: {}'.format(pointhere))
        points0.append(pointhere)

    flux = reverse_norm(points0[0], normals[0], deltae_cut[0])
    return flux

print(mini_data('darkmtesting', normals[0])*cut_energy[0]**2)
print((normals[0][0])/units[0]*(cut_energy[0])**2)
# Out:
# ./pymultinest_chains/darkmtesting/chain3/3stats.json
# pointhere: 1.0012694688530555
# 1.6458212562433655e-05
# 1.6437345863832622e-05

# %%
'''
Collect the data from the files created
'''

#getting errors and stuff for the dark matter stuff
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points = []
errors = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:])

def reverse_norm(arr, norm, deltae, egb = False):
    adjusted_arr = np.array(arr)*np.array(norm)
    counts = adjusted_arr*196608 #counts
    per = counts/(exposure_time*8500*.2) #counts divided by 13 years in seconds /.85m^2/.2
    fin = per/4/np.pi/deltae
    return fin #counts per MeV per sec per str per cm^2

def make_json():
    for idx in range(3, len(energies)):
    #for idx in range(3, 4):
        # !python3 ./pymultinest_chains/multinest_marginals.py ./pymultinest_chains/all/chain{idx}/{idx}

def make_plot(path, normals, index, colors = 'blue', label = 'none', save = False):
    
    flux, err = get_data(path, normals, index)
    print(np.shape(err))
    get_plot(flux, err, normals, path, color_ofpoints = colors, label_forplot = label, savefig = save)
    return flux, err, normals, path
    
def get_plot(flux, errors, normals, path, color_ofpoints = 'blue', label_forplot = 'none', savefig = False):
    plt.figure(figsize=(10, 8), dpi=80)
    fntsz = 20
    sizeofdot = 150
    units = deltae_cut*8500*exposure_time*4*np.pi/196608*.2
    cut_energy = energies[3:]
    print(cut_energy)
    norm = 1
    plt.scatter(cut_energy, flux*cut_energy**2*norm, label = label_forplot, color = color_ofpoints, s = sizeofdot, marker = '*')
    plt.scatter(cut_energy, normals/units*cut_energy**2, color = 'teal', alpha = .5, s = sizeofdot)
    #plt.errorbar(cut_energy, flux*cut_energy**2, yerr = errors*cut_energy**2, color = 'black', ls = 'none')
    plt.ylabel(r'MeV/cm^2/s/str', fontsize=fntsz)
    plt.xlabel('MeV', fontsize = fntsz)
    plt.yscale('log')
    plt.xscale('log')
    plt.ylim(1e-8, 3e2)
    plt.legend()
    if savefig:
        plt.savefig('images/{}_10yrs.pdf'.format(label_forplot))
    #plt.show()

def merge(list1, list2):
      
    merged_list = tuple(zip(list1, list2)) 
    return merged_list
    
def get_data(path, normals, num):  
    points0 = []
    errors1 = []
    errors2 = []

    f = []
    mypath = './pymultinest_chains/' + str(path) + '/'
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.append(dirnames)
    chains_list = f[0]

    for number in range(3, len(energies)):
    #for number in range(3, range_num+3):
        file = 'chain' + str(number)
        number = re.sub('\D', '', str(file))
        path_to_this_file = mypath + file + '/' + str(number) + 'stats.json'
        f = open(path_to_this_file)
        filehere = json.load(f)
        #print(path_to_this_file)
        pointhere = (10**(filehere['marginals'][num]['median']))
        print(filehere['marginals'][num]['median'])
        print(pointhere)
        points0.append(pointhere)
        #errors = 10**np.array((filehere['marginals'][num]['1sigma']))
        errors = np.array((filehere['marginals'][num]['1sigma']))

        errors1.append(np.abs(errors[0]-pointhere))
        errors2.append(np.abs(errors[1]-pointhere))
    print(points0)
    flux = reverse_norm(points0, normals, deltae_cut)
    flux_err_up = reverse_norm(errors1, normals, deltae_cut)
    flux_err_down = reverse_norm(errors2, normals, deltae_cut)
    
    
    
    errors = merge(flux_err_up, flux_err_down)
    
    return flux, [flux_err_up, flux_err_down]

# %%
make_json()
# Out:
# model "./pymultinest_chains/all/chain3/3"
#   analysing data from ./pymultinest_chains/all/chain3/3.txt
#   marginal likelihood:
#     ln Z = -3536255719.2 +- 0.0
#   parameters:
#     a0             0.49541722 +- 0.00000010
#     a1             -0.00916556 +- 0.00000021
#     a2             -0.7722403 +- 0.0000019
#     a3             -0.999947 +- 0.000056
#     a4             0.00839671 +- 0.00000019
# creating marginal plot ...
# model "./pymultinest_chains/all/chain4/4"
#   analysing data from ./pymultinest_chains/all/chain4/4.txt
#   marginal likelihood:
#     ln Z = -31425313032.5 +- 0.0
#   parameters:
#     a0             0.466727734 +- 0.000000042
#     a1             -0.066544532 +- 0.000000085
#     a2             -0.999999999987 +- 0.000000000016
#     a3             -0.99990 +- 0.00011
#     a4             0.04441146 +- 0.00000017
# creating marginal plot ...
# model "./pymultinest_chains/all/chain5/5"
#   analysing data from ./pymultinest_chains/all/chain5/5.txt
#   marginal likelihood:
#     ln Z = -89551914063.5 +- 0.0
#   parameters:
#     a0             0.428019968 +- 0.000000051
#     a1             -0.14396006 +- 0.00000010
#     a2             -0.999999999989 +- 0.000000000013
#     a3             0.99999961 +- 0.00000048
#     a4             0.08898896 +- 0.00000019
# creating marginal plot ...
# model "./pymultinest_chains/all/chain6/6"
#   analysing data from ./pymultinest_chains/all/chain6/6.txt
#   marginal likelihood:
#     ln Z = -114937889029.1 +- 0.7
#   parameters:
#     a0             0.397003295 +- 0.000000060
#     a1             -0.20599341 +- 0.00000012
#     a2             -0.999999999987 +- 0.000000000015
#     a3             0.99999983 +- 0.00000018
#     a4             0.11880048 +- 0.00000022
# creating marginal plot ...
# model "./pymultinest_chains/all/chain7/7"
#   analysing data from ./pymultinest_chains/all/chain7/7.txt
#   marginal likelihood:
#     ln Z = -111135061859.2 +- 0.0
#   parameters:
#     a0             0.375612464 +- 0.000000065
#     a1             -0.24877507 +- 0.00000013
#     a2             -0.999999999982 +- 0.000000000020
#     a3             0.99999987 +- 0.00000017
#     a4             0.13974645 +- 0.00000023
# creating marginal plot ...
# model "./pymultinest_chains/all/chain8/8"
#   analysing data from ./pymultinest_chains/all/chain8/8.txt
#   marginal likelihood:
#     ln Z = -100004425714.2 +- 0.0
#   parameters:
#     a0             0.356289206 +- 0.000000074
#     a1             -0.28742159 +- 0.00000015
#     a2             -0.999999999975 +- 0.000000000027
#     a3             0.99999988 +- 0.00000013
#     a4             0.15662615 +- 0.00000027
# creating marginal plot ...
# model "./pymultinest_chains/all/chain9/9"
#   analysing data from ./pymultinest_chains/all/chain9/9.txt
#   marginal likelihood:
#     ln Z = -85850600230.3 +- 0.0
#   parameters:
#     a0             0.336423064 +- 0.000000080
#     a1             -0.32715387 +- 0.00000016
#     a2             -0.999999999959 +- 0.000000000048
#     a3             0.99999990 +- 0.00000013
#     a4             0.16259379 +- 0.00000028
# creating marginal plot ...
# model "./pymultinest_chains/all/chain10/10"
#   analysing data from ./pymultinest_chains/all/chain10/10.txt
#   marginal likelihood:
#     ln Z = -70919285185.5 +- 0.0
#   parameters:
#     a0             0.317652134 +- 0.000000098
#     a1             -0.36469573 +- 0.00000020
#     a2             -0.999999999936 +- 0.000000000082
#     a3             0.99999991 +- 0.00000011
#     a4             0.16362966 +- 0.00000033
# creating marginal plot ...
# model "./pymultinest_chains/all/chain11/11"
#   analysing data from ./pymultinest_chains/all/chain11/11.txt
#   marginal likelihood:
#     ln Z = -57736666393.7 +- 0.0
#   parameters:
#     a0             0.30003226 +- 0.00000011
#     a1             -0.39993548 +- 0.00000023
#     a2             -0.99999999988 +- 0.00000000013
#     a3             0.99999991 +- 0.00000011
#     a4             0.17079939 +- 0.00000036
# creating marginal plot ...
# model "./pymultinest_chains/all/chain12/12"
#   analysing data from ./pymultinest_chains/all/chain12/12.txt
#   marginal likelihood:
#     ln Z = -45861088825.3 +- 0.0
#   parameters:
#     a0             0.28717575 +- 0.00000014
#     a1             -0.42564850 +- 0.00000028
#     a2             -0.99999999980 +- 0.00000000024
#     a3             0.99999991 +- 0.00000010
#     a4             0.19046190 +- 0.00000046
# creating marginal plot ...
# model "./pymultinest_chains/all/chain13/13"
#   analysing data from ./pymultinest_chains/all/chain13/13.txt
#   marginal likelihood:
#     ln Z = -35811437897.2 +- 0.0
#   parameters:
#     a0             0.27663798 +- 0.00000016
#     a1             -0.44672404 +- 0.00000033
#     a2             -0.99999999972 +- 0.00000000034
#     a3             0.999999921 +- 0.000000092
#     a4             0.21251453 +- 0.00000057
# creating marginal plot ...
# model "./pymultinest_chains/all/chain14/14"
#   analysing data from ./pymultinest_chains/all/chain14/14.txt
#   marginal likelihood:
#     ln Z = -27406858559.5 +- 0.0
#   parameters:
#     a0             0.26618698 +- 0.00000020
#     a1             -0.46762604 +- 0.00000040
#     a2             -0.99999999953 +- 0.00000000059
#     a3             0.999999924 +- 0.000000089
#     a4             0.21578657 +- 0.00000066
# creating marginal plot ...
# model "./pymultinest_chains/all/chain15/15"
#   analysing data from ./pymultinest_chains/all/chain15/15.txt
#   marginal likelihood:
#     ln Z = -20469976564.2 +- 0.0
#   parameters:
#     a0             0.25865259 +- 0.00000023
#     a1             -0.48269482 +- 0.00000046
#     a2             -0.99999999925 +- 0.00000000081
#     a3             0.999999917 +- 0.000000090
#     a4             0.20883751 +- 0.00000074
# creating marginal plot ...
# model "./pymultinest_chains/all/chain16/16"
#   analysing data from ./pymultinest_chains/all/chain16/16.txt
#   marginal likelihood:
#     ln Z = -15158660178.4 +- 0.0
#   parameters:
#     a0             0.25367316 +- 0.00000027
#     a1             -0.49265368 +- 0.00000053
#     a2             -0.9999999990 +- 0.0000000012
#     a3             0.999999919 +- 0.000000091
#     a4             0.20532678 +- 0.00000086
# creating marginal plot ...
# model "./pymultinest_chains/all/chain17/17"
#   analysing data from ./pymultinest_chains/all/chain17/17.txt
#   marginal likelihood:
#     ln Z = -11164503089.1 +- 0.0
#   parameters:
#     a0             0.25236772 +- 0.00000034
#     a1             -0.49526456 +- 0.00000068
#     a2             -0.9999999987 +- 0.0000000016
#     a3             0.99999990 +- 0.00000011
#     a4             0.2084842 +- 0.0000011
# creating marginal plot ...
# model "./pymultinest_chains/all/chain18/18"
#   analysing data from ./pymultinest_chains/all/chain18/18.txt
#   marginal likelihood:
#     ln Z = -8053327663.2 +- 0.0
#   parameters:
#     a0             0.25408054 +- 0.00000044
#     a1             -0.49183892 +- 0.00000088
#     a2             -0.9999999982 +- 0.0000000021
#     a3             0.99999989 +- 0.00000014
#     a4             0.2060373 +- 0.0000013
# creating marginal plot ...
# model "./pymultinest_chains/all/chain19/19"
#   analysing data from ./pymultinest_chains/all/chain19/19.txt
#   marginal likelihood:
#     ln Z = -5717165779.1 +- 0.0
#   parameters:
#     a0             0.25611850 +- 0.00000052
#     a1             -0.4877630 +- 0.0000010
#     a2             -0.9999999973 +- 0.0000000032
#     a3             0.99999985 +- 0.00000017
#     a4             0.1948100 +- 0.0000015
# creating marginal plot ...
# model "./pymultinest_chains/all/chain20/20"
#   analysing data from ./pymultinest_chains/all/chain20/20.txt
#   marginal likelihood:
#     ln Z = -3953066006.0 +- 0.0
#   parameters:
#     a0             0.25939081 +- 0.00000060
#     a1             -0.4812184 +- 0.0000012
#     a2             -0.9999999960 +- 0.0000000044
#     a3             0.99999978 +- 0.00000024
#     a4             0.1766351 +- 0.0000018
# creating marginal plot ...
# model "./pymultinest_chains/all/chain21/21"
#   analysing data from ./pymultinest_chains/all/chain21/21.txt
#   marginal likelihood:
#     ln Z = -2697907113.0 +- 0.0
#   parameters:
#     a0             0.26261913 +- 0.00000079
#     a1             -0.4747617 +- 0.0000016
#     a2             -0.9999999941 +- 0.0000000068
#     a3             0.99999966 +- 0.00000038
#     a4             0.1597069 +- 0.0000021
# creating marginal plot ...
# model "./pymultinest_chains/all/chain22/22"
#   analysing data from ./pymultinest_chains/all/chain22/22.txt
#   marginal likelihood:
#     ln Z = -1840286378.1 +- 0.0
#   parameters:
#     a0             0.26524892 +- 0.00000086
#     a1             -0.4695022 +- 0.0000017
#     a2             -0.999999991 +- 0.000000011
#     a3             0.99999946 +- 0.00000065
#     a4             0.1499899 +- 0.0000023
# creating marginal plot ...
# model "./pymultinest_chains/all/chain23/23"
#   analysing data from ./pymultinest_chains/all/chain23/23.txt
#   marginal likelihood:
#     ln Z = -1242724428.3 +- 0.0
#   parameters:
#     a0             0.2681170 +- 0.0000012
#     a1             -0.4637660 +- 0.0000024
#     a2             -0.999999985 +- 0.000000017
#     a3             0.9999989 +- 0.0000012
#     a4             0.1435513 +- 0.0000029
# creating marginal plot ...
# model "./pymultinest_chains/all/chain24/24"
#   analysing data from ./pymultinest_chains/all/chain24/24.txt
#   marginal likelihood:
#     ln Z = -821690236.3 +- 0.1
#   parameters:
#     a0             0.2704726 +- 0.0000013
#     a1             -0.4590548 +- 0.0000027
#     a2             -0.999999978 +- 0.000000030
#     a3             0.9999977 +- 0.0000027
#     a4             0.1315083 +- 0.0000033
# creating marginal plot ...
# model "./pymultinest_chains/all/chain25/25"
#   analysing data from ./pymultinest_chains/all/chain25/25.txt
#   marginal likelihood:
#     ln Z = -532038865.8 +- 0.0
#   parameters:
#     a0             0.2720377 +- 0.0000018
#     a1             -0.4559245 +- 0.0000036
#     a2             -0.999999961 +- 0.000000046
#     a3             0.9999948 +- 0.0000061
#     a4             0.1157718 +- 0.0000043
# creating marginal plot ...
# model "./pymultinest_chains/all/chain26/26"
#   analysing data from ./pymultinest_chains/all/chain26/26.txt
#   marginal likelihood:
#     ln Z = -342303261.6 +- 0.1
#   parameters:
#     a0             0.2734963 +- 0.0000021
#     a1             -0.4530074 +- 0.0000041
#     a2             -0.999999932 +- 0.000000082
#     a3             0.999982 +- 0.000022
#     a4             0.1048637 +- 0.0000048
# creating marginal plot ...
# model "./pymultinest_chains/all/chain27/27"
#   analysing data from ./pymultinest_chains/all/chain27/27.txt
#   marginal likelihood:
#     ln Z = -217743907.4 +- 0.2
#   parameters:
#     a0             0.2743089 +- 0.0000027
#     a1             -0.4513823 +- 0.0000053
#     a2             -0.99999988 +- 0.00000014
#     a3             0.999937 +- 0.000073
#     a4             0.0952149 +- 0.0000059
# creating marginal plot ...
# model "./pymultinest_chains/all/chain28/28"
#   analysing data from ./pymultinest_chains/all/chain28/28.txt
#   marginal likelihood:
#     ln Z = -137320638.2 +- 0.0
#   parameters:
#     a0             0.2747050 +- 0.0000034
#     a1             -0.4505900 +- 0.0000068
#     a2             -0.99999981 +- 0.00000022
#     a3             0.99975 +- 0.00031
#     a4             0.0873812 +- 0.0000071
# creating marginal plot ...
# model "./pymultinest_chains/all/chain29/29"
#   analysing data from ./pymultinest_chains/all/chain29/29.txt
#   marginal likelihood:
#     ln Z = -86875093.4 +- 0.4
#   parameters:
#     a0             0.2739503 +- 0.0000042
#     a1             -0.4520995 +- 0.0000083
#     a2             -0.99999966 +- 0.00000039
#     a3             0.9991 +- 0.0010
#     a4             0.0845968 +- 0.0000093
# creating marginal plot ...
# model "./pymultinest_chains/all/chain30/30"
#   analysing data from ./pymultinest_chains/all/chain30/30.txt
#   marginal likelihood:
#     ln Z = -54907061.7 +- 0.0
#   parameters:
#     a0             0.2718528 +- 0.0000054
#     a1             -0.456294 +- 0.000011
#     a2             -0.99999941 +- 0.00000073
#     a3             0.989 +- 0.014
#     a4             0.084724 +- 0.000012
# creating marginal plot ...
# model "./pymultinest_chains/all/chain31/31"
#   analysing data from ./pymultinest_chains/all/chain31/31.txt
#   marginal likelihood:
#     ln Z = -33804633.6 +- 0.0
#   parameters:
#     a0             0.2677255 +- 0.0000068
#     a1             -0.464549 +- 0.000014
#     a2             -0.9999988 +- 0.0000014
#     a3             -0.02 +- 0.67
#     a4             0.081328 +- 0.000015
# creating marginal plot ...
# model "./pymultinest_chains/all/chain32/32"
#   analysing data from ./pymultinest_chains/all/chain32/32.txt
#   marginal likelihood:
#     ln Z = -20600771.9 +- 0.1
#   parameters:
#     a0             0.2612572 +- 0.0000083
#     a1             -0.477486 +- 0.000017
#     a2             -0.9999980 +- 0.0000022
#     a3             -0.02 +- 0.63
#     a4             0.078953 +- 0.000018
# creating marginal plot ...
# model "./pymultinest_chains/all/chain33/33"
#   analysing data from ./pymultinest_chains/all/chain33/33.txt
#   marginal likelihood:
#     ln Z = -12045393.3 +- 0.0
#   parameters:
#     a0             0.251666 +- 0.000011
#     a1             -0.496668 +- 0.000022
#     a2             -0.9999962 +- 0.0000045
#     a3             0.01 +- 0.66
#     a4             0.070843 +- 0.000024
# creating marginal plot ...
# model "./pymultinest_chains/all/chain34/34"
#   analysing data from ./pymultinest_chains/all/chain34/34.txt
#   marginal likelihood:
#     ln Z = -6771239.8 +- 0.1
#   parameters:
#     a0             0.238698 +- 0.000014
#     a1             -0.522604 +- 0.000028
#     a2             -0.9999914 +- 0.0000093
#     a3             -0.00 +- 0.66
#     a4             0.060168 +- 0.000026
# creating marginal plot ...
# model "./pymultinest_chains/all/chain35/35"
#   analysing data from ./pymultinest_chains/all/chain35/35.txt
#   marginal likelihood:
#     ln Z = -3940562.2 +- 0.0
#   parameters:
#     a0             0.221715 +- 0.000020
#     a1             -0.556570 +- 0.000040
#     a2             -0.999984 +- 0.000018
#     a3             0.00 +- 0.69
#     a4             0.063385 +- 0.000038
# creating marginal plot ...
# model "./pymultinest_chains/all/chain36/36"
#   analysing data from ./pymultinest_chains/all/chain36/36.txt
#   marginal likelihood:
#     ln Z = -2248633.5 +- 0.0
#   parameters:
#     a0             0.201053 +- 0.000024
#     a1             -0.597893 +- 0.000048
#     a2             -0.999971 +- 0.000037
#     a3             0.03 +- 0.67
#     a4             0.070619 +- 0.000054
# creating marginal plot ...
# model "./pymultinest_chains/all/chain37/37"
#   analysing data from ./pymultinest_chains/all/chain37/37.txt
#   marginal likelihood:
#     ln Z = -1193905.2 +- 0.0
#   parameters:
#     a0             0.177116 +- 0.000033
#     a1             -0.645768 +- 0.000065
#     a2             -0.999936 +- 0.000081
#     a3             -0.04 +- 0.71
#     a4             0.068158 +- 0.000078
# creating marginal plot ...

# %%
fluxdm, errdm, normalsdm, pathdm = make_plot('/all/', normals[3][0], 3, colors = 'green', label = 'DM', save = True)
# Out:
# 1.902882142344407
# 79.96172276112469
# -6.634260030156785
# 2.3213464935553885e-07
# 1.988585681797118
# 97.40599382967568
# -6.172598792197912
# 6.720494156402047e-07
# 0.9247609100327978
# 8.409320600702694
# -6.405948979293139
# 3.926910658474076e-07
# -6.411978490615902
# 3.8727682517845357e-07
# -6.404844529859309
# 3.9369098500243305e-07
# -6.568635936173643
# 2.7000018630266117e-07
# -6.506576592024135
# 3.114751531033031e-07
# -6.384121182498927
# 4.129322641784362e-07
# -6.273524843991106
# 5.326907506619706e-07
# -6.175880194449015
# 6.669907415541937e-07
# -6.036593073693635
# 9.191934612515847e-07
# -5.864718856591849
# 1.3654667945067999e-06
# -5.410644346110731
# 3.884683615754546e-06
# 1.475771870800879
# 29.906932519636854
# 1.6233249016862878
# 42.0073128964455
# 1.7532567473700833
# 56.6574138860271
# 1.983632958298464
# 96.30147927042687
# 2.173955468305632
# 149.2641349249898
# 2.36748090540362
# 233.06706405900493
# 2.5868541100826645
# 386.23720893075284
# 2.876964723885551
# 753.2943739675309
# 3.2879740991201962
# 1940.7701285908736
# 3.7196869372837087
# 5244.292872523374
# 4.11574569197234
# 13054.062629258306
# 5.075506646785612
# 118988.95400295808
# -0.7187771595201036
# 0.19108334732381332
# -1.4933215175401964
# 0.03211282277112998
# -0.9433741176953654
# 0.11392679562144162
# -1.42310129790591
# 0.03774841335963934
# -1.2129482068754087
# 0.061242342380944434
# -0.791386668209039
# 0.16166400431348782
# -0.782809966549017
# 0.16488837327687897
# [79.96172276112469, 2.3213464935553885e-07, 97.40599382967568, 6.720494156402047e-07, 8.409320600702694, 3.926910658474076e-07, 3.8727682517845357e-07, 3.9369098500243305e-07, 2.7000018630266117e-07, 3.114751531033031e-07, 4.129322641784362e-07, 5.326907506619706e-07, 6.669907415541937e-07, 9.191934612515847e-07, 1.3654667945067999e-06, 3.884683615754546e-06, 29.906932519636854, 42.0073128964455, 56.6574138860271, 96.30147927042687, 149.2641349249898, 233.06706405900493, 386.23720893075284, 753.2943739675309, 1940.7701285908736, 5244.292872523374, 13054.062629258306, 118988.95400295808, 0.19108334732381332, 0.03211282277112998, 0.11392679562144162, 0.03774841335963934, 0.061242342380944434, 0.16166400431348782, 0.16488837327687897]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]

# %%
fluxpi, errpi, normalspi, pathpi = make_plot('/all/', normals[0], 0, colors = 'red', label = 'Pi', save = True)
fluxics, errics, normalsics, pathics = make_plot('/all/', normals[1], 1, colors = 'orange', label = 'ICS', save = True)
fluxbrem, errbrem, normalsbrem, pathbrem = make_plot('/all/', normals[2], 2, colors = 'goldenrod', label = 'Bremm', save = True)

fluxdm, errdm, normalsdm, pathdm = make_plot('/all/', normals[3][0], 3, colors = 'green', label = 'DM', save = True)
fluxegb, erregb, normalsegb, pathegb = make_plot('/all/', normals[4], 4, colors = 'blue', label = 'egb', save = True)
# Out:
# 0.49541721987921233
# 3.1290839854260923
# 0.46672773386605954
# 2.929056397387276
# 0.42801996781722157
# 2.679291509375822
# 0.39700329508525917
# 2.494613654039287
# 0.3756124639732509
# 2.3747202956240163
# 0.3562892058405968
# 2.2713769060845532
# 0.3364230644883448
# 2.169816785255891
# 0.3176521337223616
# 2.078031534283726
# 0.30003226165662933
# 1.9954105389535706
# 0.28717575000635553
# 1.9372057524989161
# 0.2766379795410824
# 1.890766850615468
# 0.2661869823206546
# 1.8458099481343735
# 0.25865259194991264
# 1.8140639460695533
# 0.25367316000770895
# 1.793383459889956
# 0.25236771935651076
# 1.788000843564088
# 0.2540805423099872
# 1.7950665009604558
# 0.25611849605706943
# 1.8035097564196285
# 0.25939080624325034
# 1.817150116386404
# 0.2626191342629287
# 1.830708231420526
# 0.26524892429779956
# 1.8418273780368404
# 0.26811701520488473
# 1.8540311015653979
# 0.2704725948650536
# 1.864114543963701
# 0.2720377279839999
# 1.8708446571245254
# 0.2734962968586683
# 1.8771384123266712
# 0.27430887146877553
# 1.8806538676608135
# 0.27470498247241565
# 1.8823699555943814
# 0.27395025440670967
# 1.8791015656777579
# 0.27185283255884785
# 1.8700483380148443
# 0.26772548262088225
# 1.8523603769820784
# 0.2612572225669046
# 1.824976273484591
# 0.25166583939424547
# 1.7851135206371889
# 0.2386979122573133
# 1.7325984129713314
# 0.22171514561448755
# 1.6661540212193313
# 0.20105337457283332
# 1.588741992189582
# 0.1771161559116998
# 1.5035440485106975
# [3.1290839854260923, 2.929056397387276, 2.679291509375822, 2.494613654039287, 2.3747202956240163, 2.2713769060845532, 2.169816785255891, 2.078031534283726, 1.9954105389535706, 1.9372057524989161, 1.890766850615468, 1.8458099481343735, 1.8140639460695533, 1.793383459889956, 1.788000843564088, 1.7950665009604558, 1.8035097564196285, 1.817150116386404, 1.830708231420526, 1.8418273780368404, 1.8540311015653979, 1.864114543963701, 1.8708446571245254, 1.8771384123266712, 1.8806538676608135, 1.8823699555943814, 1.8791015656777579, 1.8700483380148443, 1.8523603769820784, 1.824976273484591, 1.7851135206371889, 1.7325984129713314, 1.6661540212193313, 1.588741992189582, 1.5035440485106975]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]
# -0.009165560241575322
# 0.9791166587850038
# -0.0665445322678809
# 0.857937137907533
# -0.1439600643655569
# 0.7178602992213371
# -0.2059934098294816
# 0.6223097282919243
# -0.24877507205349822
# 0.5639296482448617
# -0.2874215883188064
# 0.5159153049494238
# -0.32715387102331034
# 0.47081048815782106
# -0.36469573255527676
# 0.43182150574775763
# -0.39993547668674134
# 0.39816632189669793
# -0.42564849998728893
# 0.3752766127514892
# -0.44672404091783524
# 0.35749992833863353
# -0.46762603535869085
# 0.34070143646318185
# -0.48269481610017473
# 0.3290828000429439
# -0.49265367998458215
# 0.32162242342068686
# -0.4952645612869785
# 0.319694701658589
# -0.4918389153800256
# 0.32222637428704143
# -0.48776300788586113
# 0.3252647441500788
# -0.4812183875134993
# 0.3302034545483121
# -0.4747617314741426
# 0.3351492628590871
# -0.4695021514044009
# 0.3392328090486062
# -0.46376596959023053
# 0.3437431325571803
# -0.45905481026989287
# 0.34749230330169967
# -0.4559245440320003
# 0.3500059731091383
# -0.4530074062826635
# 0.3523648619032295
# -0.451382257062449
# 0.3536858969947576
# -0.4505900350551687
# 0.35433166497243934
# -0.45209949118658066
# 0.3531022694132601
# -0.45629433488230436
# 0.3497080786512081
# -0.4645490347582355
# 0.3431238966213188
# -0.4774855548661908
# 0.3330538398781704
# -0.4966683212115091
# 0.3186630281561699
# -0.5226041754853734
# 0.30018972606307764
# -0.5565697087710249
# 0.27760692224253486
# -0.5978932508543333
# 0.2524101117746522
# -0.6457676881766004
# 0.2260644705811939
# [0.9791166587850038, 0.857937137907533, 0.7178602992213371, 0.6223097282919243, 0.5639296482448617, 0.5159153049494238, 0.47081048815782106, 0.43182150574775763, 0.39816632189669793, 0.3752766127514892, 0.35749992833863353, 0.34070143646318185, 0.3290828000429439, 0.32162242342068686, 0.319694701658589, 0.32222637428704143, 0.3252647441500788, 0.3302034545483121, 0.3351492628590871, 0.3392328090486062, 0.3437431325571803, 0.34749230330169967, 0.3500059731091383, 0.3523648619032295, 0.3536858969947576, 0.35433166497243934, 0.3531022694132601, 0.3497080786512081, 0.3431238966213188, 0.3330538398781704, 0.3186630281561699, 0.30018972606307764, 0.27760692224253486, 0.2524101117746522, 0.2260644705811939]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]
# -0.7722402797271183
# 0.1689505929331982
# -0.999999999986752
# 0.10000000000305045
# -0.9999999999890548
# 0.10000000000252024
# -0.9999999999873309
# 0.10000000000291717
# -0.9999999999816669
# 0.10000000000422135
# -0.999999999974527
# 0.10000000000586537
# -0.9999999999589286
# 0.10000000000945704
# -0.9999999999356949
# 0.1000000000148068
# -0.9999999998837201
# 0.10000000002677444
# -0.999999999804322
# 0.10000000004505653
# -0.9999999997157909
# 0.10000000006544156
# -0.9999999995269696
# 0.10000000010891927
# -0.9999999992523565
# 0.10000000017215128
# -0.9999999990247002
# 0.10000000022457109
# -0.9999999987101166
# 0.10000000029700663
# -0.9999999982016323
# 0.10000000041408946
# -0.9999999973237654
# 0.10000000061622578
# -0.9999999960212401
# 0.10000000091614332
# -0.9999999941256545
# 0.10000000135261804
# -0.9999999911489966
# 0.10000000203801887
# -0.9999999854297702
# 0.10000000335491945
# -0.9999999777459777
# 0.10000000512417813
# -0.9999999612762263
# 0.10000000891647881
# -0.9999999316896233
# 0.10000001572904674
# -0.9999998833782137
# 0.10000002685316228
# -0.9999998145421164
# 0.10000004270326493
# -0.9999996563837605
# 0.10000007912059437
# -0.9999994103551146
# 0.10000013577084449
# -0.9999988492082874
# 0.10000026497993533
# -0.9999979546413443
# 0.10000047096234406
# -0.9999962077218703
# 0.10000087320812144
# -0.9999914322738964
# 0.10000197281130037
# -0.9999844499279803
# 0.10000358060050472
# -0.9999710272266766
# 0.10000667145012704
# -0.9999358838358399
# 0.10001476438220915
# [0.1689505929331982, 0.10000000000305045, 0.10000000000252024, 0.10000000000291717, 0.10000000000422135, 0.10000000000586537, 0.10000000000945704, 0.1000000000148068, 0.10000000002677444, 0.10000000004505653, 0.10000000006544156, 0.10000000010891927, 0.10000000017215128, 0.10000000022457109, 0.10000000029700663, 0.10000000041408946, 0.10000000061622578, 0.10000000091614332, 0.10000000135261804, 0.10000000203801887, 0.10000000335491945, 0.10000000512417813, 0.10000000891647881, 0.10000001572904674, 0.10000002685316228, 0.10000004270326493, 0.10000007912059437, 0.10000013577084449, 0.10000026497993533, 0.10000047096234406, 0.10000087320812144, 0.10000197281130037, 0.10000358060050472, 0.10000667145012704, 0.10001476438220915]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]
# -0.9999473558192035
# 0.1000121225053098
# -0.9999014408812457
# 0.10002269665106242
# 0.9999996055172294
# 9.999990916702655
# 0.9999998290775073
# 9.999996064364936
# 0.9999998683741829
# 9.999996969204016
# 0.99999988447446
# 9.999997339926491
# 0.9999999011811677
# 9.999997724612557
# 0.9999999084140521
# 9.999997891155838
# 0.9999999097498062
# 9.999997921912708
# 0.9999999129211411
# 9.999997994935377
# 0.9999999206695372
# 9.999998173348757
# 0.9999999237135501
# 9.99999824343973
# 0.9999999169191331
# 9.999998086992528
# 0.9999999192730311
# 9.999998141193021
# 0.9999999049796157
# 9.999997812075033
# 0.9999998866733282
# 9.999997390557288
# 0.9999998496864066
# 9.999996538902206
# 0.9999997821412938
# 9.999994983619166
# 0.9999996620253471
# 9.999992217849051
# 0.999999460681422
# 9.99998758173853
# 0.9999989367834348
# 9.99997551856383
# 0.9999976768236211
# 9.99994650703009
# 0.9999948358229657
# 9.999881091136404
# 0.999981909969055
# 9.999583470319232
# 0.9999370473231678
# 9.998550566100704
# 0.9997480712733399
# 9.994200808876222
# 0.999097328277981
# 9.97923680089595
# 0.9891673960501665
# 9.753655137166618
# -0.017571046933181213
# 0.9603487005461412
# -0.01760001501834086
# 0.9602846460017698
# 0.012741048279184097
# 1.0297719272178723
# -0.004536837019008149
# 0.9896079213982597
# 0.0022376327411146838
# 1.005165635921541
# 0.02594265151023984
# 1.0615553697925502
# -0.04470272723422513
# 0.9021884705550484
# [0.1000121225053098, 0.10002269665106242, 9.999990916702655, 9.999996064364936, 9.999996969204016, 9.999997339926491, 9.999997724612557, 9.999997891155838, 9.999997921912708, 9.999997994935377, 9.999998173348757, 9.99999824343973, 9.999998086992528, 9.999998141193021, 9.999997812075033, 9.999997390557288, 9.999996538902206, 9.999994983619166, 9.999992217849051, 9.99998758173853, 9.99997551856383, 9.99994650703009, 9.999881091136404, 9.999583470319232, 9.998550566100704, 9.994200808876222, 9.97923680089595, 9.753655137166618, 0.9603487005461412, 0.9602846460017698, 1.0297719272178723, 0.9896079213982597, 1.005165635921541, 1.0615553697925502, 0.9021884705550484]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]
# 0.00839671496899966
# 1.0195222658023686
# 0.04441145700342839
# 1.107672712493864
# 0.08898895500725088
# 1.227408015277058
# 0.1188004838475091
# 1.3146207528343312
# 0.13974644754493423
# 1.3795785954448156
# 0.15662614553785678
# 1.4342542502466
# 0.16259378535269886
# 1.4540983624361001
# 0.16362966189147854
# 1.457570808528137
# 0.17079939238100086
# 1.4818334442900338
# 0.19046190188861076
# 1.550464767634706
# 0.2125145324278913
# 1.631227492696619
# 0.21578656893641193
# 1.643563806476142
# 0.2088375144314501
# 1.6174747675120094
# 0.20532677899606658
# 1.6044521849133906
# 0.2084841898382261
# 1.616159389976811
# 0.20603726840811054
# 1.6070791564737938
# 0.19480999714419805
# 1.5660657699700764
# 0.17663514471553052
# 1.5018796912824453
# 0.1597069346291211
# 1.444464705519113
# 0.1499899087508203
# 1.412504723338285
# 0.14355127000500012
# 1.3917180824062731
# 0.13150826292305784
# 1.3536558451955338
# 0.11577176470262283
# 1.305484634925698
# 0.10486365099008556
# 1.2731033208617961
# 0.09521487901765771
# 1.2451305216113162
# 0.08738124254793184
# 1.2228726798447764
# 0.08459676357908132
# 1.2150573128290811
# 0.08472402562508834
# 1.2154134152990606
# 0.08132776626278132
# 1.205945735970301
# 0.07895250215033849
# 1.199368123674355
# 0.07084284289965104
# 1.1771799131708864
# 0.0601676419756916
# 1.1485969057283407
# 0.06338455041408016
# 1.1571363867496243
# 0.07061898497780345
# 1.176573289887759
# 0.0681575038789931
# 1.1699236057035762
# [1.0195222658023686, 1.107672712493864, 1.227408015277058, 1.3146207528343312, 1.3795785954448156, 1.4342542502466, 1.4540983624361001, 1.457570808528137, 1.4818334442900338, 1.550464767634706, 1.631227492696619, 1.643563806476142, 1.6174747675120094, 1.6044521849133906, 1.616159389976811, 1.6070791564737938, 1.5660657699700764, 1.5018796912824453, 1.444464705519113, 1.412504723338285, 1.3917180824062731, 1.3536558451955338, 1.305484634925698, 1.2731033208617961, 1.2451305216113162, 1.2228726798447764, 1.2150573128290811, 1.2154134152990606, 1.205945735970301, 1.199368123674355, 1.1771799131708864, 1.1485969057283407, 1.1571363867496243, 1.176573289887759, 1.1699236057035762]
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]

# %%
def reverse_norm(arr, norm, deltae, egb = False):
    adjusted_arr = np.array(arr)*np.array(norm)
    counts = adjusted_arr*196608 #counts
    per = counts/(exposure_time*8500*.2) #counts divided by 13 years in seconds /.85m^2/.2
    fin = per/4/np.pi/deltae
    return fin #counts per MeV per sec per str per cm^2


print(10**(0.9247609642428997)/8500/exposure_time/4/np.pi*196608/.2/deltae_cut[4])
print((10**(0.9247609642428997)/units)[4])

print(reverse_norm(10**(0.9247609642428997), normalsdm[4], deltae_cut[4], egb = False))
# Out:
# 2.293187863449445e-15
# 2.293187863449445e-15
# 7.285108686131291e-09

# %%
print((fluxdm*cut_energy**2)[4])
# Out:
# 0.0007144578661453391

# %%
plt.figure(figsize=(10, 8), dpi=80)
fntsz = 20
sizeofdot = 150
units = deltae_cut*8500*exposure_time*4*np.pi/196608*.2
cut_energy = energies[3:]
print(cut_energy)
plt.scatter(cut_energy, fluxpi*cut_energy**2, label = 'Pi', color = 'Red', s = sizeofdot, marker = '*')
plt.scatter(cut_energy, normalspi/units*cut_energy**2, color = 'purple', alpha = .5, s = sizeofdot)

plt.scatter(cut_energy, fluxics*cut_energy**2, label = 'ICS', color = 'Orange', s = sizeofdot, marker = '*')
plt.scatter(cut_energy, normalsics/units*cut_energy**2, color = 'purple', alpha = .5, s = sizeofdot)

plt.scatter(cut_energy, fluxbrem*cut_energy**2, label = 'Bremm', color = 'Yellow', s = sizeofdot, marker = '*')
plt.scatter(cut_energy, normalsbrem/units*cut_energy**2, color = 'purple', alpha = .5, s = sizeofdot)

plt.scatter(cut_energy, fluxdm*cut_energy**2, label = 'DM', color = 'green', s = sizeofdot, marker = '*')
plt.scatter(cut_energy, normalsdm/units*cut_energy**2, color = 'purple', alpha = .5, s = sizeofdot)
plt.scatter(cut_energy[4], (reverse_norm(10**(0.9247609642428997), normalsdm[4], deltae_cut[4], egb = False)*cut_energy[4]**2), color = 'black', s = sizeofdot, alpha = .4)

plt.scatter(cut_energy, fluxegb*cut_energy**2, label = 'EGB', color = 'blue', s = sizeofdot, marker = '*')
plt.scatter(cut_energy, normalsegb/units*cut_energy**2, color = 'purple', alpha = .5, s = sizeofdot)
#plt.errorbar(cut_energy, flux*cut_energy**2, yerr = errors*cut_energy**2, color = 'black', ls = 'none')
plt.ylabel(r'MeV/cm^2/s/str', fontsize=fntsz)
plt.xlabel('MeV', fontsize = fntsz)
plt.yscale('log')
plt.xscale('log')
plt.ylim(1e-14, 3e2)
plt.legend()
# Out:
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]

# %%
make_plot('darkmtesting', normals[0], colors = 'goldenrod', label = 'DM Test', save = True)
# Out:
# ./pymultinest_chains/darkmtesting/chain3/3stats.json
# ./pymultinest_chains/darkmtesting/chain4/4stats.json
# ./pymultinest_chains/darkmtesting/chain5/5stats.json
# ./pymultinest_chains/darkmtesting/chain6/6stats.json
# ./pymultinest_chains/darkmtesting/chain7/7stats.json
# ./pymultinest_chains/darkmtesting/chain8/8stats.json
# ./pymultinest_chains/darkmtesting/chain9/9stats.json
# ./pymultinest_chains/darkmtesting/chain10/10stats.json
# ./pymultinest_chains/darkmtesting/chain11/11stats.json
# ./pymultinest_chains/darkmtesting/chain12/12stats.json
# ./pymultinest_chains/darkmtesting/chain13/13stats.json
# ./pymultinest_chains/darkmtesting/chain14/14stats.json
# ./pymultinest_chains/darkmtesting/chain15/15stats.json
# ./pymultinest_chains/darkmtesting/chain16/16stats.json
# ./pymultinest_chains/darkmtesting/chain17/17stats.json
# ./pymultinest_chains/darkmtesting/chain18/18stats.json
# ./pymultinest_chains/darkmtesting/chain19/19stats.json
# ./pymultinest_chains/darkmtesting/chain20/20stats.json
# ./pymultinest_chains/darkmtesting/chain21/21stats.json
# ./pymultinest_chains/darkmtesting/chain22/22stats.json
# ./pymultinest_chains/darkmtesting/chain23/23stats.json
# ./pymultinest_chains/darkmtesting/chain24/24stats.json
# ./pymultinest_chains/darkmtesting/chain25/25stats.json
# ./pymultinest_chains/darkmtesting/chain26/26stats.json
# ./pymultinest_chains/darkmtesting/chain27/27stats.json
# ./pymultinest_chains/darkmtesting/chain28/28stats.json
# ./pymultinest_chains/darkmtesting/chain29/29stats.json
# ./pymultinest_chains/darkmtesting/chain30/30stats.json
# ./pymultinest_chains/darkmtesting/chain31/31stats.json
# ./pymultinest_chains/darkmtesting/chain32/32stats.json
# ./pymultinest_chains/darkmtesting/chain33/33stats.json
# ./pymultinest_chains/darkmtesting/chain34/34stats.json
# ./pymultinest_chains/darkmtesting/chain35/35stats.json
# ./pymultinest_chains/darkmtesting/chain36/36stats.json
# ./pymultinest_chains/darkmtesting/chain37/37stats.json
# (2, 35)
# [1.09762971e+02 1.42654170e+02 1.85401433e+02 2.40958196e+02
#  3.13162910e+02 4.07004243e+02 5.28965751e+02 6.87473830e+02
#  8.93479900e+02 1.16121705e+03 1.50918340e+03 1.96142017e+03
#  2.54917267e+03 3.31304908e+03 4.30582611e+03 5.59609532e+03
#  7.27300221e+03 9.45240533e+03 1.22848810e+04 1.59661266e+04
#  2.07504819e+04 2.69685007e+04 3.50497899e+04 4.55526908e+04
#  5.92028552e+04 7.69433815e+04 9.99999737e+04 1.29965626e+05
#  1.68910683e+05 2.19525884e+05 2.85308264e+05 3.70802769e+05
#  4.81916266e+05 6.26325656e+05 8.14008272e+05]
