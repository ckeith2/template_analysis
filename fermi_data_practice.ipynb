# %%
import numpy as np
from astropy.io import fits
import astropy
import matplotlib.pyplot as plt
import fermipy

# %%
#!wget https://fermi.gsfc.nasa.gov/FTP/fermi/data/lat/queries/L210524143629F283DED931_PH01.fits
#!wget https://fermi.gsfc.nasa.gov/FTP/fermi/data/lat/queries/L210524143629F283DED931_SC00.fits
#!wget https://fermi.gsfc.nasa.gov/FTP/fermi/data/lat/queries/L210524143629F283DED931_PH00.fits

# %%
file_list = ['L210524143629F283DED931_PH01.fits', 'L210524143629F283DED931_SC00.fits', 'L210524143629F283DED931_PH00.fits']

# %%
hdu1 = fits.open(file_list[0])
hdu2 = fits.open(file_list[1])
hdu3 = fits.open(file_list[2])

# %%
hdu1.info()
hdu2.info()
hdu3.info()
# Out:
# Filename: L210524143629F283DED931_PH01.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      31   ()
#   1  EVENTS        1 BinTableHDU    208   5600R x 23C   [E, E, E, E, E, E, E, E, E, D, J, J, I, 3I, 32X, 32X, I, D, E, E, E, E, E]
#   2  GTI           1 BinTableHDU     46   1452R x 2C   [D, D]
# Filename: L210524143629F283DED931_SC00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  SC_DATA       1 BinTableHDU    514   438180R x 31C   [D, D, 3E, E, E, D, E, E, E, E, E, E, L, E, E, E, E, E, E, E, J, B, I, D, D, D, D, D, E, E, 3E]
# Filename: L210524143629F283DED931_PH00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      31   ()
#   1  EVENTS        1 BinTableHDU    208   5913R x 23C   [E, E, E, E, E, E, E, E, E, D, J, J, I, 3I, 32X, 32X, I, D, E, E, E, E, E]
# ...

# %%
print(hdu3[2].header)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                   16 / length of dimension 1                          NAXIS2  =                 1287 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                    2 / number of table fields                         TELESCOP= 'GLAST   '           / name of telescope generating data              INSTRUME= 'LAT     '           / name of instrument generating data             EQUINOX =                2000. / equinox for ra and dec                         RADECSYS= 'FK5     '           / world coord. system for this file (FK5 or FK4) DATE    = '2021-05-24T14:36:31' / file
# ...

# %%
plt.hist(hdu1[2].data)
# Out:
# ([array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
#   array([2., 0., 0., 0., 0., 0., 0., 0., 0., 0.]),
# ...
