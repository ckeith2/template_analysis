# %%
from iminuit import Minuit
import matplotlib.pyplot as plt
from matplotlib import transforms
from matplotlib import rc
from IPython.display import Image
import numpy as np
from astropy.io import fits as pyfits
from astropy.io import fits
from scipy.ndimage import gaussian_filter
import scipy
from scipy.optimize import minimize, rosen, rosen_der
from scipy.special import factorial
import scipy.integrate as integrate
from scipy.integrate import quad
from itertools import starmap
from scipy import optimize
import corner
import time
from mpl_toolkits import mplot3d
import healpy as hp
from scipy import nan
import dark_matter_jfactors_test as dmj
import math
import random
import importlib
from pymultinest.solve import solve
import pymultinest
import warnings
warnings.filterwarnings("ignore")
import scipy as sp
import scipy.interpolate
import json
from os import walk
import re

# %%
filelist = ['Bremss_00320087_E_50-814008_MeV_healpix_128.fits', 'Bremss_SL_Z6_R20_T100000_C5_E_50-814008_MeV_healpix_128.fits', 'pi0_Model_A_E_50-814008_MeV_healpix_128.fits', 'pi0_Model_F_E_50-814008_MeV_healpix_128.fits', 'ICS_Model_A_E_50-814008_MeV_healpix_128.fits', 'ICS_Model_F_E_50-814008_MeV_healpix_128.fits']
evermore_shifted = np.asarray([
    [33, 21, 49],
    [154, 112, 82],
    [241, 149, 91],
    [142, 52, 38],
    [33, 21, 49],
])/256

#exposure_time = 4.1e6 #.13 years 47 days
#exposure_time = 4.1e8 #13 years
#exposure_time = 4.1e9 #130 years
#exposure_time = 4.1e11 #13000 years
exposure_time = 4.1e17 #this should be plenty of time 
#exposure_time = 3.154e10

# %%
def log_interp1d(xx, yy, kind='linear'):
    logx = np.log10(xx)
    logy = np.log10(yy)
    lin_interp = sp.interpolate.interp1d(logx, logy, kind=kind, fill_value="extrapolate")
    log_interp = lambda zz: np.power(10.0, lin_interp(np.log10(zz)))
    return log_interp

def get_all_egb_data(energies, deltae):
    energy_range = np.array([(.1, .14), (.14, .2), (.2, .28), (.28, .4), (.4, .57), (.57, .8), (.8, 1.1), (1.1, 1.6), (1.6, 2.3), (2.3, 3.2), (3.2, 4.5), (4.5, 6.4), (6.4, 9.1), (9.1, 13), (13, 18), (18, 26), (26, 36), (36, 51), (51, 72), (72, 100), (100, 140), (140, 200), (200, 290), (290, 410), (410, 580), (580, 820)])*1e3 #GeV to MeV
    egb_intensity = np.array([3.7e-6, 2.3e-6, 1.5e-6, 9.7e-7, 6.7e-7, 4.9e-7, 3e-7, 1.8e-7, 1.1e-7, 6.9e-8, 4.2e-8, 2.6e-8, 1.7e-8, 1.2e-8, 6.8e-9, 4.4e-9, 2.7e-9, 1.8e-9, 1.1e-9, 6.2e-10, 3.1e-10, 1.9e-10, 8.9e-11, 6.3e-11, 2.1e-11, 9.7e-12])
    middle_bin = []
    bin_width = []
    for i in range(0, len(energy_range)):
        low_e = np.log10(energy_range[i][0])
        high_e = np.log10(energy_range[i][1])
        difference = np.abs((low_e+high_e)/2)
        middle_bin.append(10**(difference))
        bin_width.append(np.abs(energy_range[i][1]-(10**(difference)))) 
    return middle_bin, bin_width, egb_intensity

def get_all_egb(energies, deltae):
    energy_range = np.array([(.1, .14), (.14, .2), (.2, .28), (.28, .4), (.4, .57), (.57, .8), (.8, 1.1), (1.1, 1.6), (1.6, 2.3), (2.3, 3.2), (3.2, 4.5), (4.5, 6.4), (6.4, 9.1), (9.1, 13), (13, 18), (18, 26), (26, 36), (36, 51), (51, 72), (72, 100), (100, 140), (140, 200), (200, 290), (290, 410), (410, 580), (580, 820)])*1e3 #GeV to MeV
    egb_intensity = np.array([3.7e-6, 2.3e-6, 1.5e-6, 9.7e-7, 6.7e-7, 4.9e-7, 3e-7, 1.8e-7, 1.1e-7, 6.9e-8, 4.2e-8, 2.6e-8, 1.7e-8, 1.2e-8, 6.8e-9, 4.4e-9, 2.7e-9, 1.8e-9, 1.1e-9, 6.2e-10, 3.1e-10, 1.9e-10, 8.9e-11, 6.3e-11, 2.1e-11, 9.7e-12])
    middle_bin = []
    bin_width = []
    for i in range(0, len(energy_range)):
        low_e = np.log10(energy_range[i][0])
        high_e = np.log10(energy_range[i][1])
        difference = np.abs((low_e+high_e)/2)
        middle_bin.append(10**(difference))
        bin_width.append(np.abs(energy_range[i][1]-(10**(difference)))) 
        

    log_interp = log_interp1d(middle_bin, egb_intensity/bin_width, kind='linear')

    
    counts = []
    #only want energies from 3 onward (about lowest at 80 MeV)
    for x in range(3, len(energies)):
        highest_val = energies[x]+deltae[x]
        lowest_val = energies[x]-deltae[x]
        x_trapz = np.logspace(np.log10(lowest_val), np.log10(highest_val), num = 400)
        #counts.append(log_interp(energies[x])*deltae[x])
        total_counts = np.trapz(log_interp(x_trapz), x = x_trapz)
        
        #print('total counts: {}'.format(total_counts))
        '''
        plt.scatter(middle_bin, egb_intensity/bin_width)
        plt.plot(x_trapz, log_interp(x_trapz), color = 'red')
        plt.scatter(energies[x], total_counts)
        
        plt.yscale('log')
        plt.xscale('log')
        asdfads
        '''
        counts.append(total_counts)  
    return counts #returns counts per cm^2 per sec per str

# %%
def readfile(filename):
    """
    A simple function to read the maps of a given number n and given filename.
    """
    file_to_read = fits.open(filename)
    return file_to_read

def reshape_file(hdu, n, inner20 = True):
    """
    Reshapes the data to be in the size we want
    """
    
    if inner20:
        numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
        NSIDE = int(hdu[0].header['NSIDE'])
        degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
        vec = hp.ang2vec(np.pi/2, 0)
        ipix_disc20 = hp.query_disc(nside=NSIDE, vec=vec, radius=np.radians(20), inclusive = False)
        
        data4 = hdu[n].data
        test20 = np.copy(data4)[ipix_disc20]
        
        #might need this for plotting, not sure
        #data4 = hdu[n].data
        #test20 = np.copy(data4)
        #test20[inner_20] = np.nan
        #testbin = np.reshape(test20, (128*3, 1536//3))

    else:
        """
        testbin = np.reshape(hdu[n].data, (128*3, 1536//3))
        
        """
        numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
        NSIDE = int(hdu[0].header['NSIDE'])
        degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
        
        inner_20_pos = (np.sqrt((degrees[0])**2+degrees[1]**2)> 20)
        inner_20_neg = (np.sqrt((degrees[0]-360)**2+degrees[1]**2)> 20)
        inner_20 = np.logical_and(inner_20_pos, inner_20_neg)
        
        data4 = hdu[n].data
        test20 = np.copy(data4)
        #test20[inner_20] = np.nan
        #print(sum(~np.isnan(test20)))
        #testbin = np.reshape(test20, (128*3, 1536//3))
        
    return test20

def get_energy_index(E_desired, hdu):
    energy_hdu = np.concatenate(hdu[38].data, axis = 0)
    idx = find_nearest(energy_hdu, E_desired)
    return idx
    
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
def subtract(n):
    ##Template for 1 GeV and 10 GeV
    icsa = readfile(filelist[n])
    
    idx1 = get_energy_index(1*1e3, icsa)
    idx10 = get_energy_index(10*1e3, icsa)
    
    array1 = reshape_file(icsa, idx1, inner20 = False)
    array10 = reshape_file(icsa, idx10, inner20 = False)
    
    ##Sum up idx1 and idx 10, make them equal in sum
    sum1 = np.nansum(array1)
    sum10 = np.nansum(array10)
    array10_adjusted = (array10*sum1/sum10)
    subtract110 = np.abs(array1-array10_adjusted)/array1
    fig, ax = plt.subplots(figsize=(10, 10))
    image = ax.imshow(subtract110)
    fig.colorbar(image, ax=ax, anchor=(0, 0.3), shrink=0.7)
    plt.title(str(filelist[n]))
    
    return

# %%
#n = 4 for ICSA, n = 2 for pi0
def psf_smoothing(n, energyidx, inner20psf = False):
    icsa = readfile(filelist[n])
    hdu = readfile(filelist[n])

    inner20psf = False
    
    data50 = reshape_file(icsa, energyidx, inner20 = inner20psf) #get the data at 50 MeV
    
    #get_where_within_20deg
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    vec = hp.ang2vec(np.pi/2, 0)
    ipix_disc = hp.query_disc(nside=NSIDE, vec=vec, radius=np.radians(20), inclusive = False)
    
    init_sum = np.sum(data50[ipix_disc])
    
    data50_convolved = hp.sphtfunc.smoothing(data50.flatten(), sigma=np.pi/180/1.508)
    fin_sum = np.sum(data50_convolved[ipix_disc])

    #only get data within 20 degrees
    
    
    testbin = data50_convolved[ipix_disc]
    #print(len(testbin))


    return np.array(testbin)*init_sum/fin_sum

def psf_smoothing_DM(energyidx, crosssec = 2.2e-26, anal_data = False, mass_dm = 100):
    energybin = np.concatenate(readfile(filelist[0])[38].data, axis = 0)[energyidx]
    bins_in_lin = np.log10(energybin)
    deltae = get_deltaE(energyidx)
    
    highe = (energybin+deltae)/1e3
    lowe = (energybin-deltae)/1e3
    
    hdu = readfile(filelist[0])
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    
    degrees = hp.pix2ang(NSIDE, np.array(numpix,dtype=np.int), lonlat = True)
    
    
    #need to make sure the initsum is *only within the inner 20 degrees, same for finsum
    data50 = dmj.get_dNdE(highe, lowe, sigmav = crosssec, analyze_data = anal_data, massx = mass_dm)[1] #photons per cm^2 per sec per str per MeV
    
    #get_where_within_20deg
    numpix = np.linspace(0, hdu[0].header['NPIX']-1, num = hdu[0].header['NPIX'])
    NSIDE = int(hdu[0].header['NSIDE'])
    vec = hp.ang2vec(np.pi/2, 0)
    ipix_disc = hp.query_disc(nside=NSIDE, vec=vec, radius=np.radians(20), inclusive = False)
    
    init_sum = np.sum(data50[ipix_disc])
    
    #hp.mollview(np.log10(data50), coord = 'G')
    
    data50_convolved = hp.sphtfunc.smoothing(data50, sigma=np.pi/180/1.508)
    fin_sum = np.sum(data50_convolved[ipix_disc])
    
    #photons per cm^2 per sec per str per MeV
    
    return np.array(data50_convolved[ipix_disc])*init_sum/fin_sum

def poisson_dist(n, energyidx, cross_section =2.2e-26, dm = False, analyze_data = False, dm_mass = 100, egb = False, counts = 0):   
    '''
    Performs a PSF smoothing of the array, before converting it into photons per pixel
    
    '''
    deltaE = get_deltaE(energyidx)
    if dm:
        convolved_data = psf_smoothing_DM(energyidx, cross_section, anal_data = analyze_data, mass_dm = dm_mass)/deltaE
    elif egb:
        convolved_data_init = np.empty(5938) #needs to be the length of the good vals
        convolved_data_init.fill(1)
        convolved_data = convolved_data_init*counts #in units of photons per cm^2 per mev per str per sec
    else:
        convolved_data = psf_smoothing(n, energyidx, cross_section) #data in units of photons cm^-2 MeV^-1 str^-1
    deltaomega = 4*np.pi/196608 #divide by num of pixels
    n_gamma = np.array(convolved_data)*deltaE*exposure_time*8500*deltaomega*.2 #13 years*.85meters^2, units of photons per pixel
    
    return n_gamma

def get_deltaE(n):
    energybins = np.concatenate(readfile(filelist[0])[38].data, axis = 0)
    bins_in_lin = np.log10(energybins)[n]
    spacing = 0.05691431
    
    high_bin = 10**(bins_in_lin + spacing)
    low_bin = 10**(bins_in_lin - spacing)
    
    deltaE = np.abs(high_bin - low_bin)
    #print('delta E: {}'.format(deltaE))
    
    return deltaE

def get_image(data):
    fig, ax = plt.subplots(figsize=(10, 10))
    image = ax.imshow(data)
    fig.colorbar(image, ax=ax, anchor=(0, 0.3), shrink=0.7)
    return

def simulated_data(energyidx, templates):
    
    '''
    Use PSF smoothed data to create a random poisson draw to obtain simulated data
    '''
    
    
    n_gammatot = 0
    for i in range(0, len(templates)):
        n_gammatot += templates[i]
    len_of_rand = len(n_gammatot)
    simdata = np.zeros(len_of_rand)
    randdata = np.random.rand(len_of_rand)
    
    
    for i in range(0, len_of_rand):
        #print(n_gammatot[i])
        if n_gammatot[i]<.01:
            if n_gammatot[i] < randdata[i]:
                simdata[i] = 0
            else:
                simdata[i] = 1
        else:
            simdata[i] = np.random.poisson(lam = n_gammatot[i])
    #print('simdata just 20: ', np.nansum(simdata))
    
    return simdata

def minimize_likelihood(energyidx, cross_sec = 2.2e-26, massdm = 100):
    pi = poisson_dist(2, energyidx)
    ics = poisson_dist(4, energyidx)   
    brem = poisson_dist(0, energyidx)

    darkm = poisson_dist(np.nan, energyidx, cross_section = cross_sec, dm = True, dm_mass = massdm)

    k = simulated_data(energyidx, [pi, ics, brem])#remove DM for accurate
    #print(np.nanmean(lamb))
    #asdfasd
    
    #Need to minimize for lamb < 50 and lamb > 50
    
    bnds = ((0, np.inf), (0, np.inf), (0, np.inf), (1e-30, np.inf))
    result = minimize(likelihood, (1, 1, 1, 1), args = (k, pi, ics, brem, darkm), bounds = bnds)
    min_likelihood = result.x
    chi2 = result.fun
    #print(result)

    return min_likelihood


def likelihood(constants, k, pi, ics, brem, dm):
    """
    Gets the Total Likelihoods from the Gaussian Regime and the Poisson Regime
    Once each has been calculated, multiplies values together for final likelihood
    """
    
    likelihood_poiss = likelihood_poisson(constants, k, pi, ics, brem, dm)
    #print('likelihood: {}'.format(likelihood_poiss)) 
    return likelihood_poiss

def merge(list1, list2):
      
    merged_list = tuple(zip(list1, list2)) 
    return merged_list

def likelihood_gaussian(constants, lamb, pi, ics):
    sigma = np.sqrt(constants[0]*pi+constants[1]*ics)
    mu = lamb
    rng = 0.5
    
    #flatten arrays
    sigma_flat = sigma.flatten()
    mu_flat = mu.flatten()
    length_flattened = len(mu_flat)
    #get arrays in sigma, mu tuple format
    ms_tuples = list(merge(mu_flat, sigma_flat))
    ms = np.array(ms_tuples, dtype = 'f,f')
    lower_bound_arr = mu_flat - rng
    upper_bound_arr = mu_flat + rng
    
    args = np.concatenate((np.full((length_flattened, 1), prob_func), lower_bound_arr.reshape((length_flattened, 1)), upper_bound_arr.reshape((length_flattened, 1)), ms.reshape((length_flattened, 1))), axis = 1)
    
    #log likelihood
    prob = list(starmap(lambda a, b, c, d: quad(a, b, c, d)[0], args))

    #reshape for testing
    l = np.sum(np.log(prob))
    likely = -2*l
    
    return likely
    
def prob_func(x, mu, sigma):
    probdens = 1/(sigma*np.sqrt(2*np.pi))*np.exp(-1/2*((x-sigma**2)/sigma)**2)
    return probdens

#def likelihood_poisson(a0):
def likelihood_poisson(a0, a1, a2, a3, a4):
#def likelihood_poisson(constants, ktest, pitest, icstest, bremtest, dmtest):
    lamb = a0*pitest+a1*icstest+a2*bremtest+a3*darkmtest+a4*egbtest
    #lamb = a0*egbtest
    
    #print(a0, a1, a2, a3)
    #print(lamb)

    #lamb = constants[0]*pitest+constants[1]*icstest+constants[2]*bremtest+constants[3]*dmtest
    
    fprob = -scipy.special.gammaln(ktest+1)+ktest*np.log(lamb)-lamb #log likelihood of poisson
    #print(fprob)
    return -2*np.nansum(fprob)

def get_curves(n, energyidx, inner20psf = True):
    icsa = readfile(filelist[n])
    data50 = reshape_file(icsa, energyidx, inner20 = inner20psf) #get the data at energyidx MeV
    delt = get_deltaE(energyidx)
    return np.asarray(data50)*exposure_time*8500*.2*delt #13 years * .85 m^2 * .2, return in photons /str
    
def get_normalizations_spectrum(deltaE, cross_sec = 2.2e-26, dm_mass = 100):
    
    range_templates = [2, 4, 0] #pi, ics, brem
    e = readfile(filelist[0])[38].data
    energies = np.array(list(e)).T[0]
    templates = []
    temp = []
    deltaomega = 4*np.pi/196608 #i think this should maybe still be total bins in whole image pre-20?


    for n in range_templates:
        temp = []
        for index in range(3, len(energies)):
            temp.append(np.nansum(get_curves(n, index))) #units of photons per str
        templates.append(np.asarray(temp)*deltaomega) #gets counts per bin


            
    return range_templates, energies, [np.array(templates[0])*.2, np.array(templates[1])*.2, np.array(templates[2])*.2] #counts per pixel
    #return range_templates, np.asarray(dm_temp)*deltaomega
    
    
def get_normalized(energyidx, normals, template_val, energies):
    '''
    Normalizes the ROI based on the shape the spectrums should have
    
    
    Do not need to use this, as long as you stay consistent across all Fermi data
    for the exposure time and collecting area
    
    '''
    
    poisson_pi = poisson_dist(template_val, int(energyidx)) #units of photons per pixel
    init_sum_pi = np.nansum(poisson_pi)
    #print(np.nansum(init_sum_pi))
    if template_val == 2:
        normval = 0
    if template_val == 4:
        normval = 1
    if template_val == 0:
        normval = 2
    print('normval for pi at 0: {}'.format(normals[normval][energyidx])) 
    print('delta E at 0: {}'.format(get_deltaE(energyidx)))
    normal_pi = normals[normval][energyidx]*get_deltaE(energyidx)
    pitest = poisson_pi*normal_pi/init_sum_pi
    print('normalization: {}'.format(np.nansum(pitest)))
    #print(np.nansum(pitest))
    
    #print('----------------------')
    
    return pitest

# %%
def get_darksusy_counts():
    x = np.loadtxt('yield_DS_keith100.dat', dtype=str).T
    energies = x[1].astype(np.float)*1e3
    yieldperann = x[2].astype(np.float)/1e3 #convert from per GeV to per MeV
    energybins = np.concatenate(readfile(filelist[0])[38].data, axis = 0)
    
    counts = []
    delta = []
    for n in range(0, 38):
        
        bins_in_lin = energybins[n]
        deltae = get_deltaE(n)
    
        highe = (bins_in_lin+deltae)
        lowe = (bins_in_lin-deltae)
        
        good_energies = np.where((energies <=highe) & (energies >= lowe))
        
        final_integral = np.trapz(yieldperann[good_energies], x = energies[good_energies])

        counts.append(final_integral)
        delta.append(deltae)
    return np.array(counts), np.array(delta)

# %%
#Get normalizations (spectra without poisson draw)
#need to run this, but don't worry about it, just goes into plot below
importlib.reload(dmj)
#gets darksusy counts for a specific dark matter mass, we don't use darksusy for these three 
counts, deltae = get_darksusy_counts()
#get normalizations for pi0, ics, bremm
temps, energies, normals = get_normalizations_spectrum(deltae, cross_sec = 2.2e-26)

# %%
#main chunk of code now
#testing pymultinest



#code that returns the log-likelihood at a specific point. cube is first parameter, everything else are random parameters
#that are not part of the fitting cube
def likelihood_poisson_multinest(cube, pitest, icstest, bremtest, ktest):
    #a0 = 10**cube[0]
    a0 = 10**cube[0]
    a1 = 10**cube[1]
    a2 = 10**cube[2]
    lamb = a0*pitest+a1*icstest+a2*bremtest
    fprob = -scipy.special.gammaln(ktest+1)+ktest*np.log(lamb)-lamb #log likelihood of poisson
    return 2*np.sum(fprob) #perhaps add negative back, perhaps add 2 back?

##This is the prior function, it is flat in linear space, from a minimum value specified by the first number, 
#to a maximum number specified by the first number + the second number. 
#The variables were called a/b/c/phi0/phi1/norm in this code.
#You need to define a prior for every parameter you send

def prior(cube, ndim, nparams):
    cube[0] = cube[0]*4 - 2
    cube[1] = cube[1]*4 - 2
    cube[2] = cube[2]*4 - 2
    #cube[4] = (cube[4]*8 - 4)
    return cube

##This is the loglikelihood function for multinest – it sends the cube,
#and then a bunch of different arrays that were used in fitting, but were constant, to the pymultinest code
def loglikelihood_formulti(cube, ndim, nparms):
    return likelihood_poisson_multinest(cube, pitest, icstest, bremtest, ktest)
    

#getting errors and stuff for the dark matter stuff
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points = []
errors = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:])


##These are the names of the parameters we are fitting.
parameters = ['a0', 'a1', 'a2']
folder = './pymultinest_chains/'
livepoints = 200

'''Check if directory exists, if not, create it'''
import os

# You should change 'test' to your preferred folder.
MYDIR1 = (folder + "updated_three_temps_test1")
CHECK_FOLDER = os.path.isdir(MYDIR1)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR1)
    print("created folder : ", MYDIR1)

else:
    print(MYDIR1, "folder already exists.")

#getting the constants in front of the poission dist. arrays
for energyidx in range(3, len(energies)):
    # You should change 'test' to your preferred folder.
    MYDIR = (MYDIR1 + "/chain" + str(energyidx))
    CHECK_FOLDER = os.path.isdir(MYDIR)

    # If folder doesn't exist, then create it.
    if not CHECK_FOLDER:
        os.makedirs(MYDIR)
        print("created folder : ", MYDIR)

    else:
        print(MYDIR, "folder already exists.")
    print(energyidx, energies[energyidx])
    pitest = poisson_dist(2, int(energyidx))
    icstest = poisson_dist(4, int(energyidx))
    bremtest = poisson_dist(0, int(energyidx))
    
    
    ktest = simulated_data(int(energyidx), [pitest, icstest, bremtest])
    
    ##This is the main part of the code – it tells pymultinest to run loglikelihood in a loop – 
    #with 6 variables defined in the prior function, and send the output to the folder we specified.
    #N_live_points tells you how many different chains to test (usually 200-1000)
    ##json.dump (requires import json) saves the output into a parameters file.
    #result = solve(LogLikelihood=likelihood_poisson_multinest, Prior=prior, n_dims=int(len(parameters)), outputfiles_basename=folder+"/params", verbose=True)
    finals = pymultinest.run(loglikelihood_formulti, prior, int(len(parameters)), outputfiles_basename=MYDIR+"/"+ str(energyidx), n_live_points=livepoints, resume=True, verbose=True)
    print('made it to here')
    json.dump(parameters, open(MYDIR+'/' + str(energyidx) + 'params' +'.json', 'w'))
    print('----------')
    
    #print('here be the likelihood for a0, a1, a2 = .1, .1, 1: {}'.format(likelihood_poisson_multinest([-1, -1, 0], pitest, icstest, bremtest, ktest)))
    #print('here be the likelihood for a0, a1, a2 = 1: {}'.format(likelihood_poisson_multinest([0, 0, 0], pitest, icstest, bremtest, ktest)))
    #print('here be the likelihood for a0, a1, a2 = 10, 10, 1: {}'.format(likelihood_poisson_multinest([1, 1, 0], pitest, icstest, bremtest, ktest)))

    #break

print('------------------')

#we now have our constants. Let's get back our adjusted plots
# Out:
# created folder :  ./pymultinest_chains/updated_three_temps_test1
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain3
# 3 109.7629710930695
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain4
# 4 142.65416981671697
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain5
# 5 185.40143331981702
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain6
# 6 240.95819646356009
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain7
# 7 313.1629103579625
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain8
# 8 407.0042433219344
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain9
# 9 528.965751061358
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain10
# 10 687.4738295408508
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain11
# 11 893.4798998900418
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain12
# 12 1161.217048859432
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain13
# 13 1509.1834015826835
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain14
# 14 1961.420168477385
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain15
# 15 2549.1726673347453
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain16
# 16 3313.049081641206
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain17
# 17 4305.826105078932
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain18
# 18 5596.095315918128
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain19
# 19 7273.00221156208
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain20
# 20 9452.405326071254
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain21
# 21 12284.880967903657
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain22
# 22 15966.126630150377
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain23
# 23 20750.481851310695
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain24
# 24 26968.50069123621
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain25
# 25 35049.78991546971
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain26
# 26 45552.69079225364
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain27
# 27 59202.85523591168
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain28
# 28 76943.38154619717
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain29
# 29 99999.97365283336
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain30
# 30 129965.62575773097
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain31
# 31 168910.68328916508
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain32
# 32 219525.8843472731
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain33
# 33 285308.2644627702
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain34
# 34 370802.7689435847
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain35
# 35 481916.2659558049
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain36
# 36 626325.6556968171
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps_test1/chain37
# 37 814008.272175696
# made it to here
# ----------
# ------------------

# %%
for idx in range(3, len(energies)):
    # !python3 ./pymultinest_chains/multinest_marginals.py ./pymultinest_chains/updated_three_temps_test1/chain{idx}/{idx}
# Out:
# model "./pymultinest_chains/updated_three_temps_test1/chain3/3"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain3/3.txt
#   marginal likelihood:
#     ln Z = -182768.7 +- 0.0
#   parameters:
#     a0             0.00000023 +- 0.00000090
#     a1             0.000000002 +- 0.000000010
#     a2             -0.00000009 +- 0.00000036
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain4/4"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain4/4.txt
#   marginal likelihood:
#     ln Z = -181403.9 +- 0.0
#   parameters:
#     a0             0.00000102 +- 0.00000064
#     a1             -0.000000004 +- 0.000000013
#     a2             -0.00000052 +- 0.00000034
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain5/5"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain5/5.txt
#   marginal likelihood:
#     ln Z = -180341.1 +- 0.0
#   parameters:
#     a0             0.00000176 +- 0.00000048
#     a1             0.000000042 +- 0.000000015
#     a2             -0.00000123 +- 0.00000033
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain6/6"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain6/6.txt
#   marginal likelihood:
#     ln Z = -178811.2 +- 0.0
#   parameters:
#     a0             -0.00000032 +- 0.00000041
#     a1             0.000000012 +- 0.000000020
#     a2             0.00000025 +- 0.00000033
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain7/7"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain7/7.txt
#   marginal likelihood:
#     ln Z = -177454.1 +- 0.0
#   parameters:
#     a0             -0.00000031 +- 0.00000034
#     a1             -0.000000083 +- 0.000000024
#     a2             0.00000038 +- 0.00000031
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain8/8"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain8/8.txt
#   marginal likelihood:
#     ln Z = -175719.6 +- 0.0
#   parameters:
#     a0             0.00000002 +- 0.00000030
#     a1             -0.000000032 +- 0.000000029
#     a2             -0.00000001 +- 0.00000030
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain9/9"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain9/9.txt
#   marginal likelihood:
#     ln Z = -174364.3 +- 0.0
#   parameters:
#     a0             -0.00000013 +- 0.00000027
#     a1             0.000000068 +- 0.000000034
#     a2             0.00000007 +- 0.00000030
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain10/10"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain10/10.txt
#   marginal likelihood:
#     ln Z = -172793.4 +- 0.0
#   parameters:
#     a0             0.00000024 +- 0.00000023
#     a1             -0.000000063 +- 0.000000042
#     a2             -0.00000021 +- 0.00000028
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain11/11"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain11/11.txt
#   marginal likelihood:
#     ln Z = -171224.9 +- 0.0
#   parameters:
#     a0             -0.00000007 +- 0.00000022
#     a1             0.000000107 +- 0.000000049
#     a2             -0.00000003 +- 0.00000030
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain12/12"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain12/12.txt
#   marginal likelihood:
#     ln Z = -168946.8 +- 0.0
#   parameters:
#     a0             -0.00000033 +- 0.00000024
#     a1             0.000000069 +- 0.000000063
#     a2             0.00000037 +- 0.00000036
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain13/13"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain13/13.txt
#   marginal likelihood:
#     ln Z = -167024.7 +- 0.0
#   parameters:
#     a0             0.00000013 +- 0.00000024
#     a1             0.000000043 +- 0.000000080
#     a2             -0.00000032 +- 0.00000041
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain14/14"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain14/14.txt
#   marginal likelihood:
#     ln Z = -164951.9 +- 0.0
#   parameters:
#     a0             0.00000003 +- 0.00000025
#     a1             0.000000139 +- 0.000000084
#     a2             -0.00000017 +- 0.00000049
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain15/15"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain15/15.txt
#   marginal likelihood:
#     ln Z = -162704.2 +- 0.0
#   parameters:
#     a0             -0.00000038 +- 0.00000030
#     a1             0.000000131 +- 0.000000099
#     a2             0.00000052 +- 0.00000063
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain16/16"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain16/16.txt
#   marginal likelihood:
#     ln Z = -160460.8 +- 0.0
#   parameters:
#     a0             0.00000017 +- 0.00000032
#     a1             -0.00000025 +- 0.00000012
#     a2             -0.00000008 +- 0.00000075
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain17/17"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain17/17.txt
#   marginal likelihood:
#     ln Z = -157887.1 +- 0.0
#   parameters:
#     a0             0.00000009 +- 0.00000038
#     a1             0.00000004 +- 0.00000013
#     a2             -0.00000041 +- 0.00000098
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain18/18"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain18/18.txt
#   marginal likelihood:
#     ln Z = -155520.6 +- 0.0
#   parameters:
#     a0             0.00000082 +- 0.00000042
#     a1             -0.00000021 +- 0.00000015
#     a2             -0.0000017 +- 0.0000013
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain19/19"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain19/19.txt
#   marginal likelihood:
#     ln Z = -153178.9 +- 0.0
#   parameters:
#     a0             0.00000019 +- 0.00000055
#     a1             -0.00000015 +- 0.00000018
#     a2             -0.0000002 +- 0.0000016
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain20/20"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain20/20.txt
#   marginal likelihood:
#     ln Z = -150713.9 +- 0.0
#   parameters:
#     a0             0.00000033 +- 0.00000063
#     a1             0.00000006 +- 0.00000023
#     a2             -0.0000014 +- 0.0000023
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain21/21"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain21/21.txt
#   marginal likelihood:
#     ln Z = -148353.4 +- 0.0
#   parameters:
#     a0             0.00000200 +- 0.00000086
#     a1             -0.00000002 +- 0.00000029
#     a2             -0.0000083 +- 0.0000031
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain22/22"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain22/22.txt
#   marginal likelihood:
#     ln Z = -145483.2 +- 0.0
#   parameters:
#     a0             -0.0000011 +- 0.0000011
#     a1             -0.00000002 +- 0.00000038
#     a2             0.0000039 +- 0.0000043
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain23/23"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain23/23.txt
#   marginal likelihood:
#     ln Z = -143417.0 +- 0.0
#   parameters:
#     a0             -0.0000006 +- 0.0000013
#     a1             0.00000080 +- 0.00000042
#     a2             -0.0000048 +- 0.0000056
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain24/24"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain24/24.txt
#   marginal likelihood:
#     ln Z = -140573.7 +- 0.0
#   parameters:
#     a0             0.0000036 +- 0.0000016
#     a1             -0.00000071 +- 0.00000050
#     a2             -0.0000131 +- 0.0000082
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain25/25"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain25/25.txt
#   marginal likelihood:
#     ln Z = -138070.1 +- 0.0
#   parameters:
#     a0             0.0000019 +- 0.0000019
#     a1             -0.00000047 +- 0.00000061
#     a2             -0.000007 +- 0.000011
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain26/26"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain26/26.txt
#   marginal likelihood:
#     ln Z = -135435.9 +- 0.0
#   parameters:
#     a0             -0.0000005 +- 0.0000024
#     a1             0.00000059 +- 0.00000077
#     a2             0.000005 +- 0.000014
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain27/27"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain27/27.txt
#   marginal likelihood:
#     ln Z = -132753.0 +- 0.0
#   parameters:
#     a0             0.0000026 +- 0.0000031
#     a1             -0.0000000 +- 0.0000011
#     a2             -0.000022 +- 0.000020
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain28/28"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain28/28.txt
#   marginal likelihood:
#     ln Z = -129893.9 +- 0.0
#   parameters:
#     a0             0.0000000 +- 0.0000037
#     a1             0.0000001 +- 0.0000012
#     a2             -0.000003 +- 0.000027
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain29/29"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain29/29.txt
#   marginal likelihood:
#     ln Z = -127294.3 +- 0.0
#   parameters:
#     a0             0.0000015 +- 0.0000054
#     a1             0.0000040 +- 0.0000017
#     a2             -0.000050 +- 0.000042
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain30/30"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain30/30.txt
#   marginal likelihood:
#     ln Z = -124362.0 +- 0.0
#   parameters:
#     a0             -0.0000032 +- 0.0000058
#     a1             0.0000031 +- 0.0000020
#     a2             0.000007 +- 0.000052
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain31/31"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain31/31.txt
#   marginal likelihood:
#     ln Z = -121656.8 +- 0.0
#   parameters:
#     a0             0.0000180 +- 0.0000077
#     a1             -0.0000059 +- 0.0000027
#     a2             -0.000107 +- 0.000077
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain32/32"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain32/32.txt
#   marginal likelihood:
#     ln Z = -118375.8 +- 0.0
#   parameters:
#     a0             -0.0000107 +- 0.0000093
#     a1             0.0000000 +- 0.0000034
#     a2             0.00011 +- 0.00011
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain33/33"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain33/33.txt
#   marginal likelihood:
#     ln Z = -115727.6 +- 0.0
#   parameters:
#     a0             0.000006 +- 0.000013
#     a1             0.0000038 +- 0.0000046
#     a2             -0.00007 +- 0.00017
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain34/34"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain34/34.txt
#   marginal likelihood:
#     ln Z = -112356.4 +- 0.0
#   parameters:
#     a0             -0.000002 +- 0.000015
#     a1             0.0000013 +- 0.0000061
#     a2             -0.00008 +- 0.00023
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain35/35"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain35/35.txt
#   marginal likelihood:
#     ln Z = -109419.3 +- 0.0
#   parameters:
#     a0             0.000003 +- 0.000018
#     a1             -0.0000167 +- 0.0000086
#     a2             0.00033 +- 0.00032
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain36/36"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain36/36.txt
#   marginal likelihood:
#     ln Z = -106052.0 +- 0.0
#   parameters:
#     a0             0.000016 +- 0.000022
#     a1             -0.000005 +- 0.000012
#     a2             -0.00023 +- 0.00047
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps_test1/chain37/37"
#   analysing data from ./pymultinest_chains/updated_three_temps_test1/chain37/37.txt
#   marginal likelihood:
#     ln Z = -102802.7 +- 0.0
#   parameters:
#     a0             0.000029 +- 0.000029
#     a1             0.000022 +- 0.000018
#     a2             -0.00130 +- 0.00078
# creating marginal plot ...

# %%
print('here be the likelihood for a0, a1, a2 from file: {}'.format(likelihood_poisson_multinest([0.00000182, -0.000000027, -0.00000067], pitest, icstest, bremtest, ktest)))
# Out:
# 1.0000041907136503
# here be the likelihood for a0, a1, a2 from file: -182825.11791992188

# %%
-182803.1387939453/-18935407753205.734
# Out:
# 9.654037619707294e-09

# %%
#main chunk of code now
#testing pymultinest



#code that returns the log-likelihood at a specific point. cube is first parameter, everything else are random parameters
#that are not part of the fitting cube
def likelihood_poisson_multinest(cube, pitest, icstest, bremtest, ktest):
    #a0 = 10**cube[0]
    a0 = 10**cube[0]
    a1 = 10**cube[1]
    a2 = 10**cube[2]
    lamb = a0*pitest+a1*icstest+a2*bremtest
    fprob = -scipy.special.gammaln(ktest+1)+ktest*np.log(lamb)-lamb #log likelihood of poisson
    return 2*np.sum(fprob) #perhaps add negative back, perhaps add 2 back?

##This is the prior function, it is flat in linear space, from a minimum value specified by the first number, 
#to a maximum number specified by the first number + the second number. 
#The variables were called a/b/c/phi0/phi1/norm in this code.
#You need to define a prior for every parameter you send

def prior(cube, ndim, nparams):
    cube[0] = (cube[0]*3-1)
    cube[1] = (cube[0]*3-1)
    cube[2] = (cube[0]*3-1)
    #cube[4] = (cube[4]*8 - 4)
    return cube

##This is the loglikelihood function for multinest – it sends the cube,
#and then a bunch of different arrays that were used in fitting, but were constant, to the pymultinest code
def loglikelihood_formulti(cube, ndim, nparms):
    return likelihood_poisson_multinest(cube, pitest, icstest, bremtest, ktest)
    

#getting errors and stuff for the dark matter stuff
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points = []
errors = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:])


##These are the names of the parameters we are fitting.
parameters = ['a0', 'a1', 'a2']
folder = './pymultinest_chains/'
livepoints = 200

'''Check if directory exists, if not, create it'''
import os

# You should change 'test' to your preferred folder.
MYDIR1 = (folder + "updated_three_temps")
CHECK_FOLDER = os.path.isdir(MYDIR1)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR1)
    print("created folder : ", MYDIR1)

else:
    print(MYDIR1, "folder already exists.")

#getting the constants in front of the poission dist. arrays
for energyidx in range(3, len(energies)):
    # You should change 'test' to your preferred folder.
    MYDIR = (MYDIR1 + "/chain" + str(energyidx))
    CHECK_FOLDER = os.path.isdir(MYDIR)

    # If folder doesn't exist, then create it.
    if not CHECK_FOLDER:
        os.makedirs(MYDIR)
        print("created folder : ", MYDIR)

    else:
        print(MYDIR, "folder already exists.")
    print(energyidx, energies[energyidx])
    pitest = poisson_dist(2, int(energyidx))
    icstest = poisson_dist(4, int(energyidx))
    bremtest = poisson_dist(0, int(energyidx))
    
    
    ktest = simulated_data(int(energyidx), [pitest, icstest, bremtest])
    
    ##This is the main part of the code – it tells pymultinest to run loglikelihood in a loop – 
    #with 6 variables defined in the prior function, and send the output to the folder we specified.
    #N_live_points tells you how many different chains to test (usually 200-1000)
    ##json.dump (requires import json) saves the output into a parameters file.
    #result = solve(LogLikelihood=likelihood_poisson_multinest, Prior=prior, n_dims=int(len(parameters)), outputfiles_basename=folder+"/params", verbose=True)
    finals = pymultinest.run(loglikelihood_formulti, prior, int(len(parameters)), outputfiles_basename=MYDIR+"/"+ str(energyidx), n_live_points=livepoints, resume=True, verbose=True)
    print('made it to here')
    json.dump(parameters, open(MYDIR+'/' + str(energyidx) + 'params' +'.json', 'w'))
    print('----------')

print('------------------')

#we now have our constants. Let's get back our adjusted plots
# Out:
# created folder :  ./pymultinest_chains/updated_three_temps
# created folder :  ./pymultinest_chains/updated_three_temps/chain3
# 3 109.7629710930695
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain4
# 4 142.65416981671697
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain5
# 5 185.40143331981702
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain6
# 6 240.95819646356009
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain7
# 7 313.1629103579625
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain8
# 8 407.0042433219344
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain9
# 9 528.965751061358
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain10
# 10 687.4738295408508
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain11
# 11 893.4798998900418
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain12
# 12 1161.217048859432
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain13
# 13 1509.1834015826835
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain14
# 14 1961.420168477385
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain15
# 15 2549.1726673347453
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain16
# 16 3313.049081641206
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain17
# 17 4305.826105078932
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain18
# 18 5596.095315918128
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain19
# 19 7273.00221156208
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain20
# 20 9452.405326071254
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain21
# 21 12284.880967903657
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain22
# 22 15966.126630150377
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain23
# 23 20750.481851310695
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain24
# 24 26968.50069123621
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain25
# 25 35049.78991546971
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain26
# 26 45552.69079225364
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain27
# 27 59202.85523591168
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain28
# 28 76943.38154619717
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain29
# 29 99999.97365283336
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain30
# 30 129965.62575773097
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain31
# 31 168910.68328916508
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain32
# 32 219525.8843472731
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain33
# 33 285308.2644627702
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain34
# 34 370802.7689435847
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain35
# 35 481916.2659558049
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain36
# 36 626325.6556968171
# made it to here
# ----------
# created folder :  ./pymultinest_chains/updated_three_temps/chain37
# 37 814008.272175696
# made it to here
# ----------
# ------------------

# %%
#this runs multinest_marginals.py for

for idx in range(3, len(energies)):
    # !python3 ./pymultinest_chains/multinest_marginals.py ./pymultinest_chains/updated_three_temps/chain{idx}/{idx}
# Out:
# model "./pymultinest_chains/updated_three_temps/chain3/3"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain3/3.txt
#   marginal likelihood:
#     ln Z = -18935387705642.6 +- 0.6
#   parameters:
#     a0             0.30926680858 +- 0.00000000068
#     a1             -0.0721995743 +- 0.0000000020
#     a2             -0.0721995743 +- 0.0000000020
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain4/4"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain4/4.txt
#   marginal likelihood:
#     ln Z = -24172639104228.7 +- 0.1
#   parameters:
#     a0             0.29968361971 +- 0.00000000099
#     a1             -0.1009491409 +- 0.0000000030
#     a2             -0.1009491409 +- 0.0000000030
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain5/5"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain5/5.txt
#   marginal likelihood:
#     ln Z = -26868400013800.8 +- 0.0
#   parameters:
#     a0             0.2891845081 +- 0.0000000012
#     a1             -0.1324464757 +- 0.0000000035
#     a2             -0.1324464757 +- 0.0000000035
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain6/6"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain6/6.txt
#   marginal likelihood:
#     ln Z = -25727339808541.3 +- 0.8
#   parameters:
#     a0             0.2799691718 +- 0.0000000012
#     a1             -0.1600924846 +- 0.0000000035
#     a2             -0.1600924846 +- 0.0000000035
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain7/7"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain7/7.txt
#   marginal likelihood:
#     ln Z = -22105393765311.3 +- 0.1
#   parameters:
#     a0             0.2728843316 +- 0.0000000019
#     a1             -0.1813470051 +- 0.0000000056
#     a2             -0.1813470051 +- 0.0000000056
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain8/8"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain8/8.txt
#   marginal likelihood:
#     ln Z = -18403544143898.8 +- 0.0
#   parameters:
#     a0             0.2663012110 +- 0.0000000021
#     a1             -0.2010963670 +- 0.0000000064
#     a2             -0.2010963670 +- 0.0000000064
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain9/9"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain9/9.txt
#   marginal likelihood:
#     ln Z = -15154031607836.8 +- 0.1
#   parameters:
#     a0             0.2592703506 +- 0.0000000036
#     a1             -0.222188948 +- 0.000000011
#     a2             -0.222188948 +- 0.000000011
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain10/10"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain10/10.txt
#   marginal likelihood:
#     ln Z = -12263996023027.2 +- 0.1
#   parameters:
#     a0             0.2523936335 +- 0.0000000040
#     a1             -0.242819099 +- 0.000000012
#     a2             -0.242819099 +- 0.000000012
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain11/11"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain11/11.txt
#   marginal likelihood:
#     ln Z = -9804501839312.1 +- 0.0
#   parameters:
#     a0             0.2459344661 +- 0.0000000049
#     a1             -0.262196602 +- 0.000000015
#     a2             -0.262196602 +- 0.000000015
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain12/12"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain12/12.txt
#   marginal likelihood:
#     ln Z = -7587701997340.7 +- 0.2
#   parameters:
#     a0             0.2411164401 +- 0.0000000064
#     a1             -0.276650680 +- 0.000000019
#     a2             -0.276650680 +- 0.000000019
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain13/13"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain13/13.txt
#   marginal likelihood:
#     ln Z = -5771205180445.5 +- 0.3
#   parameters:
#     a0             0.2375132436 +- 0.0000000066
#     a1             -0.287460269 +- 0.000000020
#     a2             -0.287460269 +- 0.000000020
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain14/14"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain14/14.txt
#   marginal likelihood:
#     ln Z = -4357246598186.2 +- 0.1
#   parameters:
#     a0             0.2344613602 +- 0.0000000080
#     a1             -0.296615919 +- 0.000000024
#     a2             -0.296615919 +- 0.000000024
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain15/15"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain15/15.txt
#   marginal likelihood:
#     ln Z = -3207272126469.2 +- 0.0
#   parameters:
#     a0             0.2326493452 +- 0.0000000091
#     a1             -0.302051965 +- 0.000000027
#     a2             -0.302051965 +- 0.000000027
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain16/16"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain16/16.txt
#   marginal likelihood:
#     ln Z = -2311962759800.9 +- 0.0
#   parameters:
#     a0             0.231929039 +- 0.000000011
#     a1             -0.304212883 +- 0.000000034
#     a2             -0.304212883 +- 0.000000034
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain17/17"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain17/17.txt
#   marginal likelihood:
#     ln Z = -1627272573382.7 +- 0.2
#   parameters:
#     a0             0.232787387 +- 0.000000015
#     a1             -0.301637839 +- 0.000000044
#     a2             -0.301637839 +- 0.000000044
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain18/18"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain18/18.txt
#   marginal likelihood:
#     ln Z = -1116127442666.8 +- 0.0
#   parameters:
#     a0             0.234845890 +- 0.000000018
#     a1             -0.295462331 +- 0.000000054
#     a2             -0.295462331 +- 0.000000054
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain19/19"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain19/19.txt
#   marginal likelihood:
#     ln Z = -755924050162.3 +- 0.0
#   parameters:
#     a0             0.237005468 +- 0.000000020
#     a1             -0.288983597 +- 0.000000060
#     a2             -0.288983597 +- 0.000000060
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain20/20"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain20/20.txt
#   marginal likelihood:
#     ln Z = -502325606633.2 +- 0.0
#   parameters:
#     a0             0.239414575 +- 0.000000027
#     a1             -0.281756274 +- 0.000000080
#     a2             -0.281756274 +- 0.000000080
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain21/21"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain21/21.txt
#   marginal likelihood:
#     ln Z = -330401857117.4 +- 0.1
#   parameters:
#     a0             0.241569730 +- 0.000000035
#     a1             -0.27529081 +- 0.00000011
#     a2             -0.27529081 +- 0.00000011
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain22/22"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain22/22.txt
#   marginal likelihood:
#     ln Z = -216114120206.3 +- 0.0
#   parameters:
#     a0             0.243256567 +- 0.000000037
#     a1             -0.27023030 +- 0.00000011
#     a2             -0.27023030 +- 0.00000011
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain23/23"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain23/23.txt
#   marginal likelihood:
#     ln Z = -139825867818.2 +- 0.1
#   parameters:
#     a0             0.244781517 +- 0.000000048
#     a1             -0.26565545 +- 0.00000014
#     a2             -0.26565545 +- 0.00000014
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain24/24"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain24/24.txt
#   marginal likelihood:
#     ln Z = -89849046257.1 +- 0.0
#   parameters:
#     a0             0.245963837 +- 0.000000059
#     a1             -0.26210849 +- 0.00000018
#     a2             -0.26210849 +- 0.00000018
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain25/25"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain25/25.txt
#   marginal likelihood:
#     ln Z = -57406696230.0 +- 0.1
#   parameters:
#     a0             0.246709935 +- 0.000000069
#     a1             -0.25987020 +- 0.00000021
#     a2             -0.25987020 +- 0.00000021
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain26/26"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain26/26.txt
#   marginal likelihood:
#     ln Z = -36374198502.8 +- 0.1
#   parameters:
#     a0             0.247242856 +- 0.000000086
#     a1             -0.25827143 +- 0.00000026
#     a2             -0.25827143 +- 0.00000026
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain27/27"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain27/27.txt
#   marginal likelihood:
#     ln Z = -22898058033.1 +- 0.2
#   parameters:
#     a0             0.24738994 +- 0.00000011
#     a1             -0.25783018 +- 0.00000033
#     a2             -0.25783018 +- 0.00000033
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain28/28"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain28/28.txt
#   marginal likelihood:
#     ln Z = -14318623979.2 +- 0.1
#   parameters:
#     a0             0.24723568 +- 0.00000014
#     a1             -0.25829295 +- 0.00000041
#     a2             -0.25829295 +- 0.00000041
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain29/29"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain29/29.txt
#   marginal likelihood:
#     ln Z = -8902261286.6 +- 0.1
#   parameters:
#     a0             0.24640027 +- 0.00000016
#     a1             -0.26079920 +- 0.00000047
#     a2             -0.26079920 +- 0.00000047
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain30/30"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain30/30.txt
#   marginal likelihood:
#     ln Z = -5518203991.5 +- 0.1
#   parameters:
#     a0             0.24482925 +- 0.00000024
#     a1             -0.26551225 +- 0.00000073
#     a2             -0.26551225 +- 0.00000073
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain31/31"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain31/31.txt
#   marginal likelihood:
#     ln Z = -3406720122.9 +- 0.0
#   parameters:
#     a0             0.24213568 +- 0.00000031
#     a1             -0.27359295 +- 0.00000094
#     a2             -0.27359295 +- 0.00000094
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain32/32"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain32/32.txt
#   marginal likelihood:
#     ln Z = -2096152279.3 +- 0.2
#   parameters:
#     a0             0.23810515 +- 0.00000040
#     a1             -0.2856846 +- 0.0000012
#     a2             -0.2856846 +- 0.0000012
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain33/33"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain33/33.txt
#   marginal likelihood:
#     ln Z = -1281921898.2 +- 0.2
#   parameters:
#     a0             0.23215715 +- 0.00000048
#     a1             -0.3035286 +- 0.0000015
#     a2             -0.3035286 +- 0.0000015
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain34/34"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain34/34.txt
#   marginal likelihood:
#     ln Z = -775377572.1 +- 0.4
#   parameters:
#     a0             0.22390136 +- 0.00000067
#     a1             -0.3282959 +- 0.0000020
#     a2             -0.3282959 +- 0.0000020
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain35/35"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain35/35.txt
#   marginal likelihood:
#     ln Z = -460108534.0 +- 0.0
#   parameters:
#     a0             0.2126659 +- 0.0000010
#     a1             -0.3620024 +- 0.0000031
#     a2             -0.3620024 +- 0.0000031
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain36/36"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain36/36.txt
#   marginal likelihood:
#     ln Z = -264843195.0 +- 0.1
#   parameters:
#     a0             0.1981058 +- 0.0000013
#     a1             -0.4056825 +- 0.0000038
#     a2             -0.4056825 +- 0.0000038
# creating marginal plot ...
# model "./pymultinest_chains/updated_three_temps/chain37/37"
#   analysing data from ./pymultinest_chains/updated_three_temps/chain37/37.txt
#   marginal likelihood:
#     ln Z = -145557922.8 +- 0.1
#   parameters:
#     a0             0.1797988 +- 0.0000019
#     a1             -0.4606035 +- 0.0000056
#     a2             -0.4606035 +- 0.0000056
# creating marginal plot ...

# %%
e = readfile(filelist[0])[38].data
energies = np.array(list(e)).T[0]
#cross_sec normalized to 2.2e-26
points = []
errors = []
values = []
fluxes = []
deltae_cut = np.copy(deltae[3:]) #we don't care about the very low energies

# %%
'''
Collect the data from the files created
'''

def reverse_norm(arr, norm, deltae, egb = False):
    adjusted_arr = np.array(arr)*np.array(norm)
    counts = adjusted_arr*196608 #counts
    per = counts/(exposure_time*8500*.2) #counts divided by 13 years in seconds /.85m^2/.2
    fin = per/4/np.pi/deltae
    return fin #counts per MeV per sec per str per cm^2

points0 = []
points1 = []
points2 = []

errors0 = []
errors1 = []
errors2 = []


f = []
#Change this path to wherever your chains are saved
mypath = './pymultinest_chains/updated_three_temps_test1/'
for (dirpath, dirnames, filenames) in walk(mypath):
    f.append(dirnames)
chains_list = f[0]


# i think i need to go in order of the energies, not just the list of filenames
for number in range(3, len(energies)):
    file = 'chain' + str(number)
    number = re.sub('\D', '', str(file))
    path_to_this_file = mypath + file + '/' + str(number) + 'stats.json'
    f = open(path_to_this_file)
    filehere = json.load(f)
    print(path_to_this_file)

    points0.append(10**(filehere['marginals'][0]['median']))
    points1.append(10**(filehere['marginals'][1]['median']))
    points2.append(10**(filehere['marginals'][2]['median']))

    #we don't care about errors right now
    errors0.append(10**(filehere['marginals'][0]['sigma']))
    errors1.append(10**(filehere['marginals'][1]['sigma']))
    errors2.append(10**(filehere['marginals'][2]['sigma']))
    

#just putting the normalizations from pymultinest into our correct units
piflux = reverse_norm(points0, normals[0], deltae_cut)
piflux_err = reverse_norm(errors0, normals[0], deltae_cut)
icsflux = reverse_norm(points1, normals[1], deltae_cut)
icsflux_err = reverse_norm(errors1, normals[1], deltae_cut)
bremflux = reverse_norm(points2, normals[2], deltae_cut)
bremflux_err = reverse_norm(errors2, normals[2], deltae_cut)
# Out:
# ./pymultinest_chains/updated_three_temps_test1/chain3/3stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain4/4stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain5/5stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain6/6stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain7/7stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain8/8stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain9/9stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain10/10stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain11/11stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain12/12stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain13/13stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain14/14stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain15/15stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain16/16stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain17/17stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain18/18stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain19/19stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain20/20stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain21/21stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain22/22stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain23/23stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain24/24stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain25/25stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain26/26stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain27/27stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain28/28stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain29/29stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain30/30stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain31/31stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain32/32stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain33/33stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain34/34stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain35/35stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain36/36stats.json
# ./pymultinest_chains/updated_three_temps_test1/chain37/37stats.json

# %%
plt.figure(figsize=(10, 8), dpi=80)
fntsz = 20
sizeofdot = 70
norm = 1
units = deltae_cut*8500*exposure_time*4*np.pi/196608*.2
cut_energy = energies[3:]
plt.scatter(cut_energy, piflux*cut_energy**2*norm, label = r'$\pi^0$', color = 'greenyellow', s = sizeofdot, marker = '<')
plt.scatter(cut_energy, normals[0]/units*cut_energy**2, color = 'green')
#plt.errorbar(cut_energy, piflux*cut_energy**2, yerr = piflux_err*cut_energy**2, color = 'black', ls = 'none')

plt.scatter(cut_energy, icsflux*cut_energy**2*norm, label = 'ICS', color = 'skyblue', marker = 'x', s = sizeofdot)
plt.scatter(cut_energy, normals[1]/units*cut_energy**2, color = 'blue')
#plt.errorbar(cut_energy, icsflux*cut_energy**2, yerr = icsflux_err*cut_energy**2, color = 'black', ls = 'none')

plt.scatter(cut_energy, bremflux*cut_energy**2*norm, label = 'Bremm', color = 'peachpuff', marker = 's', s = sizeofdot)
plt.scatter(cut_energy, normals[2]/units*cut_energy**2, color = 'magenta')
#plt.errorbar(cut_energy, bremflux*cut_energy**2*norm, yerr = bremflux_err*cut_energy**2, color = 'black', ls = 'none')


plt.ylabel(r'MeV/cm^2/s/str', fontsize=fntsz)
plt.xlabel('MeV', fontsize = fntsz)
#plt.legend(fontsize = 15)
plt.yscale('log')
plt.xscale('log')
#plt.ylim(1e-10, 1e-1)
plt.ylim(1e-2, 3e2)
plt.legend()
#plt.savefig('images/test_w_errors_normalexposure.pdf')
